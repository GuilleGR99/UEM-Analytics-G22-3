# %%
from tensorflow.keras import layers
import numpy as np
import json
from keras.preprocessing.text import Tokenizer
#import tensorflow_text as text
import tensorflow as tf
import pandas as pd

from tensorflow import keras

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
data = pd.read_csv("total_procesed.csv",encoding='utf-8', engine='python')

# %%
data
# Out:
#                              identifier language  \
# 0       doi:10.1007/978-3-031-16203-9_8       en
# 1       doi:10.1007/978-3-031-08246-7_7       en
# 2      doi:10.1007/978-981-19-4960-9_31       en
# 3      doi:10.1007/978-3-031-18461-1_11       en
# 4      doi:10.1007/978-981-19-7648-3_12       en
# ...                                 ...      ...
# 7336   doi:10.1007/978-3-031-08580-2_12       en
# 7337   doi:10.1007/978-3-031-17746-0_14       en
# 7338   doi:10.1007/978-981-19-6737-5_26       en
# 7339  doi:10.1007/978-3-031-11051-1_119       en
# 7340   doi:10.1007/978-3-031-21333-5_85       en
#
#                                                   title          genre  \
# 0     The Comprehensive Model of Using In-Depth Cons...  OriginalPaper
# 1     Implementation of Reinforcement-Learning Algor...  OriginalPaper
# 2     Reinforcement Learning for Autonomous Driving ...  OriginalPaper
# 3     A Survey of Reinforcement Learning Toolkits fo...  OriginalPaper
# 4      Priority-Aware Computational Resource Allocation  OriginalPaper
# ...                                                 ...            ...
# 7336  Shop Product Tracking and Early Fire Detection...  OriginalPaper
# 7337  Augmented Press and Robot Journalists Who Dete...  OriginalPaper
# 7338  Comparative Analysis of Generative Adversarial...  OriginalPaper
# 7339  Architecture of Software Complex for Multicrit...  OriginalPaper
# 7340  LEDBoard: Using Visual Feedback to Support Tex...  OriginalPaper
#
#                                                abstract  \
# 0     The paper describes the relevance of machine l...
# 1     The problem of autonomous robot navigation in ...
# 2     The decision-making process for autonomous veh...
# 3     The gaming industry has become one of the most...
# 4     Vehicular fog computing (VFC) has been expecte...
# ...                                                 ...
# 7336  With the blooming of Internet of Things techno...
# 7337  The focus is on researching the relationship b...
# 7338  In the past decade, a convolutional neural net...
# 7339  The objective of the work was to develop a com...
# 7340  Physical keyboards persist as one of the most ...
#
#                                                subjects  \
# 0     ['Engineering', 'Computational Intelligence', ...
# 1     ['Engineering', 'Computational Intelligence', ...
# 2     ['Engineering', 'Computational Intelligence', ...
# 3     ['Engineering', 'Computational Intelligence', ...
# 4     ['Computer Science', 'Computer Systems Organiz...
# ...                                                 ...
# 7336  ['Engineering', 'Computational Intelligence', ...
# 7337  ['Engineering', 'Computational Intelligence', ...
# 7338  ['Computer Science', 'Computer Communication N...
# 7339  ['Engineering', 'Control and Systems Theory', ...
# 7340  ['Engineering', 'Data Engineering', 'Computati...
#
#                                         abstract_limpio  \
# 0     the paper describes the relevance of machine l...
# 1     the problem of autonomous robot navigation in ...
# 2     the decisionmaking process for autonomous vehi...
# 3     the gaming industry has become one of the most...
# 4     vehicular fog computing vfc has been expected ...
# ...                                                 ...
# 7336  with the blooming of internet of things techno...
# 7337  the focus is on researching the relationship b...
# 7338  in the past decade a convolutional neural netw...
# 7339  the objective of the work was to develop a com...
# 7340  physical keyboards persist as one of the most ...
#
#                                                 resumen  \
# 0     the article is devoted to studying the use of ...
# 1     autonomous navigation of robots in indoor envi...
# 2     in this study , we analyze contemporary reinfo...
# 3     machine learning ml reinforcement learning gai...
# 4     in this work we propose a task offloading sche...
# ...                                                 ...
# 7336  this paper proposes an architecture for tracki...
# 7337  given the responsibility related to the import...
# 7338  in this manuscript , we have compared the perf...
# 7339  we developed a computer simulation system that...
# 7340  we present the results of a user experiment wi...
#
#                                                keywords  \
# 0     ['actingcritical models' 'ddpg' 'deep determin...
# 1     ['autonomous navigation' 'autonomous robot nav...
# 2     ['autonomous driving agents' 'autonomous drivi...
# 3     ['ai' 'aibased agents' 'artificial intelligenc...
# 4     ['actorcritic sac based' 'availability'\n 'dee...
# ...                                                 ...
# 7336  ['computer vision' 'edge' 'fire detection' 'tr...
# 7337  ['algorithms data processing' 'applications' '...
# 7338  ['##resol' 'convolutional neural network' 'dat...
# 7339  ['composite materials' 'composites' 'computer ...
# 7340  ['attention shifts' 'corrective action behavio...
#
#                                          resumen_limpio  \
# 0     the article is devoted to studying the use of ...
# 1     autonomous navigation of robots in indoor envi...
# 2     in this study  we analyze contemporary reinfor...
# 3     machine learning ml reinforcement learning gai...
# 4     in this work we propose a task offloading sche...
# ...                                                 ...
# 7336  this paper proposes an architecture for tracki...
# 7337  given the responsibility related to the import...
# 7338  in this manuscript  we have compared the perfo...
# 7339  we developed a computer simulation system that...
# 7340  we present the results of a user experiment wi...
#
#                                           resumen_plano  \
# 0     articl devot studi use ensembl neurolearn netw...
# 1     autonom navig robot indoor environ emerg field...
# 2     studi  analyz contemporari reinforc learn tech...
# 3     machin learn ml reinforc learn gain popular am...
# 4     work propos task offload scheme context vehicu...
# ...                                                 ...
# 7336  paper propos architectur track shop product de...
# 7337  given respons relat import reconsid media cont...
# 7338  manuscript  compar perform singlebas superreso...
# 7339  develop comput simul system allow solv two pro...
# 7340        present result user experi physic feedback
#
#                                          abstract_plano
# 0     paper describ relev machin learn method name t...
# 1     problem autonom robot navig indoor environ mus...
# 2     decisionmak process autonom vehicl come numer ...
# 3     game industri becom one excit creativ industri...
# 4     vehicular fog comput vfc expect promis scheme ...
# ...                                                 ...
# 7336  bloom internet thing technolog edg devic appli...
# 7337  focu research relationship journalist technici...
# 7338  past decad convolut neural network work imag b...
# 7339  object work develop comput simul system allow ...
# 7340  physic keyboard persist one common input devic...
#
# [7341 rows x 12 columns]

# %% [markdown]
# # ABSTRACTS

# %%
vocabulary = set()
data["abstract_plano"].str.lower().str.split().apply(vocabulary.update)
vocabulary_size = len(vocabulary)

# %%
text_vectorizer = layers.TextVectorization(
    max_tokens=vocabulary_size, ngrams=5, output_mode="tf-idf",pad_to_max_tokens=True
)
with tf.device("/CPU:0"):
    text_vectorizer.adapt(data["abstract_plano"])

# %%
with open("abstract_tokenizer.txt", "w") as fp:
    json.dump(text_vectorizer.get_vocabulary(), fp)

# %%
#with open("abstract_tokenizer.txt", "r") as fp:
#    b = json.load(fp)

# %% [markdown]
# # Resumenes

# %%
vocabulary = set()
data["resumen_plano"].str.lower().str.split().apply(vocabulary.update)
vocabulary_size = len(vocabulary)

# %%
text_vectorizer = layers.TextVectorization(
    max_tokens=vocabulary_size, ngrams=5, output_mode="tf-idf",pad_to_max_tokens=True
)
with tf.device("/CPU:0"):
    text_vectorizer.adapt(data["resumen_plano"])

# %%
with open("summary_tokenizer.txt", "w") as fp:
    json.dump(text_vectorizer.get_vocabulary(), fp)

# %% [markdown]
# # Subjects

# %%
vocabulary = set()
data["subjects"].str.lower().str.split().apply(vocabulary.update)
vocabulary_size = len(vocabulary)

# %%
vocabulary_size
# Out:
# 1074

# %%
text_vectorizer = layers.TextVectorization(
    max_tokens=vocabulary_size, ngrams=5, output_mode="tf-idf",pad_to_max_tokens=True
)
with tf.device("/CPU:0"):
    text_vectorizer.adapt(data["subjects"])

# %%
with open("subjects_tokenizer.txt", "w") as fp:
    json.dump(text_vectorizer.get_vocabulary(), fp)
