# %%
import pandas as pd
import os
import nltk
from nltk.corpus import stopwords
import re

# %%
dir_list = os.listdir("spring/")

# %%
dir_list = [x for x in dir_list if   ".csv" in x]
dir_list
# Out:
# ['spring_advantage actor critic.csv',
#  'spring_algorithms.csv',
#  'spring_artificial intelligence.csv',
#  'spring_computer science.csv',
#  'spring_computer.csv',
#  'spring_graph.csv',
#  'spring_health.csv',
#  'spring_law.csv',
#  'spring_machine learning.csv',
#  'spring_magic.csv',
#  'spring_natural language processing.csv',
#  'spring_optimizer.csv',
#  'spring_robotic.csv',
#  'spring_robotics.csv',
#  'spring_science.csv',
#  'total.csv']

# %%
data = pd.DataFrame()
for i in dir_list:
    if i == "total.csv":
        continue
    print(i)
    data_temp = pd.read_csv("spring/"+i)
    data = data.append(data_temp)
# Out:
# spring_advantage actor critic.csv
# spring_algorithms.csv
# spring_artificial intelligence.csv
# spring_computer science.csv
# spring_computer.csv
# spring_graph.csv
# spring_health.csv
# spring_law.csv
# spring_machine learning.csv
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# spring_magic.csv
# spring_natural language processing.csv
# spring_optimizer.csv
# spring_robotic.csv
# spring_robotics.csv
# spring_science.csv
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)
# C:\Users\yo\AppData\Local\Temp\ipykernel_3596\859499848.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data_temp)

# %%
nltk.download('stopwords')
sw_nltk = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = data.dropna()

# %%
nuevos_abs = []
for i in [ re.sub("\d+", "", x.lower().replace(".","").replace(",","").replace("b'","") ).split(" ") for x in data["abstract"].tolist() ]:
    #palabras = [h for h in i if h not in sw_nltk ]
    palabras = [h for h in i if h ]
    frase = ' '.join(palabras)
    nuevos_abs.append(frase)
data["abstract"] = nuevos_abs

# %%
total_duplicate_titles = sum(data["identifier"].duplicated())
print(f"There are {total_duplicate_titles} duplicate titles.")
# Out:
# There are 10922 duplicate titles.

# %%
data = data[~data["identifier"].duplicated()]
print(f"There are {len(data)} rows in the deduplicated dataset.")
# Out:
# There are 22494 rows in the deduplicated dataset.

# %%
areas = [ x.replace("[","").replace("]","").split("', '") for x in data["subjects"].tolist()]

#areas = [ x for x in data["subjects"].tolist() if type(x) != str ]
areas
# Out:
# [["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Computer Systems Organization and Communication Networks',
#   'Communications Engineering, Networks',
#   "Wireless and Mobile Communication'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Graph Theory',
#   'Operations Research, Management Science',
#   'Theory of Computation',
#   "Algorithm Analysis and Problem Complexity'"],
#  ["'Economics",
#   'Health Economics',
#   'Pharmaceutical Sciences/Technology',
#   'Economics, general',
#   'Biomedicine, general',
#   'Biotechnology',
#   "Economic Theory/Quantitative Economics/Mathematical Methods'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Data Engineering',
#   'Statistics, general',
#   'Machine Learning',
#   'Artificial Intelligence',
#   'Data Storage Representation',
#   "Data Structures and Information Theory'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   "Machine Learning'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   "Computer Communication Networks'"],
#  ["'Engineering", 'Computational Intelligence', "Data Engineering'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Signal, Image and Speech Processing',
#   'Communications Engineering, Networks',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Cyber-physical systems, IoT',
#   'Communications Engineering, Networks',
#   "Computer Applications'"],
#  ["'Computer Science",
#   'Computer Communication Networks',
#   'Special Purpose and Application-Based Systems',
#   'Information Systems Applications (incl.Internet)',
#   'Computer Systems Organization and Communication Networks',
#   'Computer System Implementation',
#   "Software Engineering/Programming and Operating Systems'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Robotics and Automation',
#   "User Interfaces and Human Computer Interaction'"],
#  ["'Engineering",
#   'Electrical Engineering',
#   'Automotive Engineering',
#   'Robotics and Automation',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   'Civil Engineering',
#   "User Interfaces and Human Computer Interaction'"],
#  ["'Computer Science",
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   'Artificial Intelligence',
#   'Image Processing and Computer Vision',
#   "Pattern Recognition'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Computer Science",
#   'Processor Architectures',
#   'Operating Systems',
#   "Computer Communication Networks'"],
#  ["'Engineering",
#   'Electrical Engineering',
#   'Automotive Engineering',
#   'Robotics and Automation',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   'Civil Engineering',
#   "User Interfaces and Human Computer Interaction'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Control, Robotics, Mechatronics',
#   'User Interfaces and Human Computer Interaction',
#   'Manufacturing, Machines, Tools, Processes',
#   "Electronics and Microelectronics, Instrumentation'"],
#  ["'Computer Science",
#   'Processor Architectures',
#   'Operating Systems',
#   "Computer Communication Networks'"],
#  ["'Computer Science",
#   'Processor Architectures',
#   'Operating Systems',
#   "Computer Communication Networks'"],
#  ["'Computer Science",
#   'Computer Communication Networks',
#   'Special Purpose and Application-Based Systems',
#   'Information Systems Applications (incl.Internet)',
#   'Computer Systems Organization and Communication Networks',
#   'Computer System Implementation',
#   "Software Engineering/Programming and Operating Systems'"],
#  ["'Computer Science",
#   'Programming Languages, Compilers, Interpreters',
#   'Processor Architectures',
#   "Computer Science, general'"],
#  ["'Engineering",
#   'Robotics and Automation',
#   'Artificial Intelligence',
#   'Control and Systems Theory',
#   "Machine Learning'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Mathematical Applications in the Physical Sciences',
#   "Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)'"],
#  ["'Computer Science",
#   'Computer Communication Networks',
#   'Special Purpose and Application-Based Systems',
#   'Information Systems Applications (incl.Internet)',
#   'Computer Systems Organization and Communication Networks',
#   'Computer System Implementation',
#   "Software Engineering/Programming and Operating Systems'"],
#  ["'Computer Science",
#   'Programming Languages, Compilers, Interpreters',
#   'Processor Architectures',
#   "Computer Science, general'"],
#  ["'Science, Humanities and Social Sciences, multidisciplinary",
#   'Science, Humanities and Social Sciences, multidisciplinary',
#   "Science, multidisciplinary'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Machine Learning',
#   'Control, Robotics, Mechatronics',
#   'Artificial Intelligence',
#   'Simulation and Modeling',
#   "Natural Language Processing (NLP)'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Robotics and Automation',
#   "User Interfaces and Human Computer Interaction'"],
#  ["'Computer Science",
#   'Programming Languages, Compilers, Interpreters',
#   'Processor Architectures',
#   "Computer Science, general'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   "Computer Science, general'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   "Computer Science, general'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Information Systems Applications (incl.Internet)',
#   'Database Management',
#   "Operating Systems'"],
#  ["'Computer Science",
#   'Programming Languages, Compilers, Interpreters',
#   'Processor Architectures',
#   "Computer Science, general'"],
#  ["'Physics",
#   'Particle and Nuclear Physics',
#   'Particle Acceleration and Detection, Beam Physics',
#   "Nuclear Energy'"],
#  ["'Science, Humanities and Social Sciences, multidisciplinary",
#   'Science, Humanities and Social Sciences, multidisciplinary',
#   "Science, multidisciplinary'"],
#  ["'Engineering",
#   'Industrial and Production Engineering',
#   'Media Management',
#   'Mechanical Engineering',
#   "Computer-Aided Engineering (CAD, CAE) and Design'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Complexity',
#   "Data Structures and Information Theory'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   "Computer Science, general'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Complex Systems',
#   "Computational Intelligence'"],
#  ["'Computer Science",
#   'Processor Architectures',
#   'Operating Systems',
#   "Computer Communication Networks'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Life Sciences",
#   'Bioinformatics',
#   'Microarrays',
#   'Computational Biology/Bioinformatics',
#   'Computer Appl. in Life Sciences',
#   "Algorithms'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Control, Robotics, Mechatronics',
#   'Complex Systems',
#   'Systems Biology',
#   "Pattern Recognition'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Programming Languages, Compilers, Interpreters',
#   'Processor Architectures',
#   "Computer Science, general'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Control, Robotics, Mechatronics',
#   'Complex Systems',
#   'Systems Biology',
#   "Pattern Recognition'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Computer Science",
#   'Programming Languages, Compilers, Interpreters',
#   'Processor Architectures',
#   "Computer Science, general'"],
#  ["'Psychology", 'Psychology, general', 'Sociology, general', "Anthropology'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Computer Science",
#   'Programming Languages, Compilers, Interpreters',
#   'Processor Architectures',
#   "Computer Science, general'"],
#  ["'Business and Management",
#   'Production',
#   'Manufacturing, Machines, Tools, Processes',
#   "Control, Robotics, Mechatronics'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Computer Communication Networks',
#   'Electrical Engineering',
#   "IT in Business'"],
#  ["'Computer Science",
#   'Programming Languages, Compilers, Interpreters',
#   'Processor Architectures',
#   "Computer Science, general'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Computer Science",
#   'Software Engineering/Programming and Operating Systems',
#   "Programming Languages, Compilers, Interpreters'"],
#  ["'Business and Management",
#   'IT in Business',
#   'Management of Computing and Information Systems',
#   'Systems Theory, Control',
#   "Operations Research/Decision Theory'"],
#  ["'Physics",
#   'Particle and Nuclear Physics',
#   'Particle Acceleration and Detection, Beam Physics',
#   "Nuclear Energy'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   "Computer Science, general'"],
#  ["'Engineering",
#   'Mathematical and Computational Engineering',
#   'Artificial Intelligence',
#   'Statistical Physics and Dynamical Systems',
#   'Control, Robotics, Mechatronics',
#   'Bioinformatics',
#   "Applications of Mathematics'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Robotics and Automation',
#   "User Interfaces and Human Computer Interaction'"],
#  ["'Computer Science",
#   'Computer Communication Networks',
#   'Computer Systems Organization and Communication Networks',
#   'Communications Engineering, Networks',
#   'Information Systems and Communication Service',
#   "Operations Research/Decision Theory'"],
#  ["'Computer Science",
#   'Computer Science, general',
#   'Information Systems Applications (incl.Internet)',
#   'Computer Communication Networks',
#   'Software Engineering',
#   'Artificial Intelligence',
#   "Computer Appl. in Administrative Data Processing'"],
#  ["'Environment",
#   'Sustainable Development',
#   'Environmental Management',
#   'Environmental Economics',
#   'Ecology',
#   'Economic Growth',
#   "Economic Geology'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   "Operations Research, Management Science'"],
#  ["'Business and Management",
#   'Operations Research/Decision Theory',
#   'Combinatorics',
#   "Theory of Computation'"],
#  ["'Engineering",
#   'Signal,Image and Speech Processing',
#   'Communications Engineering, Networks',
#   "Information Systems Applications (incl.Internet)'"],
#  ["'Engineering",
#   'Robotics and Automation',
#   'Artificial Intelligence',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   "Control, Robotics, Mechatronics'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Multimedia Information Systems',
#   'Computer Communication Networks',
#   'Data Structures and Information Theory',
#   "Special Purpose and Application-Based Systems'"],
#  ["'Engineering",
#   'Robotics and Automation',
#   'Artificial Intelligence',
#   'Control and Systems Theory',
#   "Machine Learning'"],
#  ["'Computer Science",
#   'Processor Architectures',
#   'Management of Computing and Information Systems',
#   "User Interfaces and Human Computer Interaction'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Mechanical Engineering',
#   "Manufacturing, Machines, Tools, Processes'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   "Computer Science, general'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   "Computer Science, general'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Complexity',
#   "Data Structures and Information Theory'"],
#  ["'Computer Science",
#   'Cryptology',
#   'Computer Communication Networks',
#   'Operating Systems',
#   'Coding and Information Theory',
#   'Management of Computing and Information Systems',
#   "Communications Engineering, Networks'"],
#  ["'Computer Science",
#   'Computer Communication Networks',
#   'Computer Systems Organization and Communication Networks',
#   'Communications Engineering, Networks',
#   'Information Systems and Communication Service',
#   "Operations Research/Decision Theory'"],
#  ["'Engineering",
#   'Robotics and Automation',
#   'Artificial Intelligence',
#   'Control and Systems Theory',
#   "Machine Learning'"],
#  ["'Business and Management",
#   'Operations Research/Decision Theory',
#   'Combinatorics',
#   "Theory of Computation'"],
#  ["'Science, Humanities and Social Sciences, multidisciplinary",
#   'Science, Humanities and Social Sciences, multidisciplinary',
#   "Science, multidisciplinary'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Information Systems and Communication Service',
#   'Computer Communication Networks',
#   "Signal,Image and Speech Processing'"],
#  ["'Engineering", "Engineering, general'"],
#  ["'Business and Management",
#   'Operations Research/Decision Theory',
#   'Combinatorics',
#   "Theory of Computation'"],
#  ["'Engineering",
#   'Control, Robotics, Mechatronics',
#   'Electrical Engineering',
#   'Artificial Intelligence',
#   "Mechanical Engineering'"],
#  ["'Business and Management",
#   'Production',
#   'Manufacturing, Machines, Tools, Processes',
#   "Control, Robotics, Mechatronics'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Psychology", "Cognitive Psychology'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Mining and Knowledge Discovery',
#   'Probability and Statistics in Computer Science',
#   'Computational Science and Engineering',
#   'Image Processing and Computer Vision',
#   "Computational Biology/Bioinformatics'"],
#  ["'Science, Humanities and Social Sciences, multidisciplinary",
#   'Science, Humanities and Social Sciences, multidisciplinary',
#   "Science, multidisciplinary'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Communications Engineering, Networks',
#   'Artificial Intelligence',
#   'Science and Technology Studies',
#   "Computer Applications'"],
#  ["'Computer Science",
#   'Machine Learning',
#   'Artificial Intelligence',
#   "Computer Science, general'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Machine Learning',
#   "Artificial Intelligence'"],
#  ["'Computer Science", "Machine Learning'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Machine Learning',
#   'Java',
#   "Data Mining and Knowledge Discovery'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   'Computers and Education',
#   "Computer Applications'"],
#  ["'Computer Science",
#   'Computer Applications',
#   'Data Mining and Knowledge Discovery',
#   'IT in Business',
#   "Machine Learning'"],
#  ["'Computer Science",
#   'Data Mining and Knowledge Discovery',
#   'Artificial Intelligence',
#   'Information Systems Applications (incl. Internet)',
#   'Database Management',
#   'Computer Appl. in Social and Behavioral Sciences',
#   "Computer Imaging, Vision, Pattern Recognition and Graphics'"],
#  ["'Engineering",
#   'Mathematical and Computational Engineering',
#   'Mechanical Engineering',
#   "Electrical Engineering'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Computing Milieux',
#   'Information Systems and Communication Service',
#   'Computer Applications',
#   "Computer Imaging, Vision, Pattern Recognition and Graphics'"],
#  ["'Engineering",
#   'Wireless and Mobile Communication',
#   'Artificial Intelligence',
#   'Computer Applications',
#   'Computing Milieux',
#   "Computer Communication Networks'"],
#  ["'Computer Science",
#   'Computer Applications',
#   'Cryptology',
#   'Mobile and Network Security',
#   "Computer Crime'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Information Systems and Communication Service',
#   'Computer Applications',
#   'Computers and Education',
#   'Computer Systems Organization and Communication Networks',
#   "Computer Imaging, Vision, Pattern Recognition and Graphics'"],
#  ["'Engineering",
#   'Control, Robotics, Mechatronics',
#   'Computational Intelligence',
#   'Communications Engineering, Networks',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Computer Applications',
#   'Data Mining and Knowledge Discovery',
#   "Image Processing and Computer Vision'"],
#  ["'Computer Science",
#   'Computer Applications',
#   'Artificial Intelligence',
#   'Systems and Data Security',
#   "Computers and Education'"],
#  ["'Computer Science",
#   'Computer Communication Networks',
#   'Wireless and Mobile Communication',
#   "Communications Engineering, Networks'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Structures and Information Theory',
#   'Software Engineering/Programming and Operating Systems',
#   'Information Systems and Communication Service',
#   "Computer Communication Networks'"],
#  ["'Computer Science",
#   'Mathematical Logic and Formal Languages',
#   'Software Engineering/Programming and Operating Systems',
#   'Information Systems and Communication Service',
#   'Artificial Intelligence',
#   "Logics and Meanings of Programs'"],
#  ["'Computer Science",
#   'Computer Science, general',
#   'Electrical Engineering',
#   'Computer Hardware',
#   'Computer Systems Organization and Communication Networks',
#   'Electronics and Microelectronics, Instrumentation',
#   "Communications Engineering, Networks'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Computational Intelligence',
#   'Computer Communication Networks',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Information Systems and Communication Service',
#   'Computing Milieux',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   "Computer Applications'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Software Engineering',
#   'Information Systems Applications (incl. Internet)',
#   'User Interfaces and Human Computer Interaction',
#   'Computer Communication Networks',
#   "Special Purpose and Application-Based Systems'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Computer Communication Networks',
#   'Data Mining and Knowledge Discovery',
#   'Information Systems Applications (incl. Internet)',
#   "Image Processing and Computer Vision'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Computational Intelligence',
#   'Computer Communication Networks',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Mathematical Logic and Foundations',
#   "Control, Robotics, Mechatronics'"],
#  ["'Computer Science", "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Theory of Computation',
#   'Computer Communication Networks',
#   'Computing Milieux',
#   'Special Purpose and Application-Based Systems',
#   'Software Engineering/Programming and Operating Systems',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Theory of Computation',
#   'Mathematics of Computing',
#   'Information Systems and Communication Service',
#   "Machine Learning'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Computer Science",
#   'Computers and Society',
#   'Information Systems and Communication Service',
#   'Artificial Intelligence',
#   'Computer Communication Networks',
#   'Computer System Implementation',
#   "Special Purpose and Application-Based Systems'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Data Structures and Information Theory',
#   'Information Systems Applications (incl. Internet)',
#   'Theory of Computation',
#   'Computer Appl. in Administrative Data Processing',
#   "Computer Appl. in Social and Behavioral Sciences'"],
#  ["'Computer Science",
#   'Special Purpose and Application-Based Systems',
#   'Computer Communication Networks',
#   'Computer Applications',
#   "Computer System Implementation'"],
#  ["'Mathematics",
#   'Mathematical Applications in Computer Science',
#   'Data Structures and Information Theory',
#   'Discrete Mathematics in Computer Science',
#   'Numerical Analysis',
#   'Algorithms',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   'Computers and Education',
#   "Computer Applications'"],
#  ["'Computer Science",
#   'Mathematics of Computing',
#   'Artificial Intelligence',
#   'Theory of Computation',
#   'Information Systems and Communication Service',
#   "Computer Systems Organization and Communication Networks'"],
#  ["'Computer Science",
#   'Computer Systems Organization and Communication Networks',
#   'Information Systems and Communication Service',
#   'Artificial Intelligence',
#   'Computer Appl. in Social and Behavioral Sciences',
#   "Computers and Education'"],
#  ["'Engineering",
#   'Cyber-physical systems, IoT',
#   'Communications Engineering, Networks',
#   "Automotive Engineering'"],
#  ["'Computer Science",
#   'Professional Computing',
#   'Algorithm Analysis and Problem Complexity',
#   'Computer Systems Organization and Communication Networks',
#   'Software Engineering/Programming and Operating Systems',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Computational Intelligence',
#   'Computer Applications',
#   "Machine Learning'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   'Information Systems and Communication Service',
#   'Computer Systems Organization and Communication Networks',
#   "Computer Appl. in Social and Behavioral Sciences'"],
#  ["'Engineering",
#   'Control, Robotics, Mechatronics',
#   "Transportation Technology and Traffic Engineering'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Machine Learning',
#   'Systems and Data Security',
#   'Mobile and Network Security',
#   "Security Science and Technology'"],
#  ["'Engineering",
#   'Data Engineering',
#   'Computational Intelligence',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Wireless and Mobile Communication',
#   "Mobile and Network Security'"],
#  ["'Computer Science",
#   'Image Processing and Computer Vision',
#   'User Interfaces and Human Computer Interaction',
#   'Computer Appl. in Social and Behavioral Sciences',
#   'Pattern Recognition',
#   'Machine Learning',
#   "Robotics'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Transportation Technology and Traffic Engineering',
#   'Mechanical Engineering',
#   'User Interfaces and Human Computer Interaction',
#   "Complexity'"],
#  ["'Computer Science",
#   'Computer Systems Organization and Communication Networks',
#   'Computer System Implementation',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   "Computer Applications'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Information Systems and Communication Service',
#   'Computer Communication Networks',
#   "Signal,Image and Speech Processing'"],
#  ["'Computer Science", 'Professional Computing', "Mobile Computing'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Mechanical Engineering',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Communications Engineering, Networks',
#   'Mobile and Network Security',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   "Multimedia Information Systems'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Information Systems and Communication Service',
#   'Computer Communication Networks',
#   "Signal,Image and Speech Processing'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Information Systems Applications (incl. Internet)',
#   'User Interfaces and Human Computer Interaction',
#   'Computer Communication Networks',
#   'Special Purpose and Application-Based Systems',
#   "Computer System Implementation'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Industrial and Production Engineering',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Water, general',
#   "Environmental Management'"],
#  ["'Business and Management",
#   'IT in Business',
#   'Computer Communication Networks',
#   'Artificial Intelligence',
#   "Probability Theory and Stochastic Processes'"],
#  ["'Engineering",
#   'Data Engineering',
#   'Cyber-physical systems, IoT',
#   'Computational Intelligence',
#   "Big Data'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   "Communications Engineering, Networks'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Database Management',
#   'User Interfaces and Human Computer Interaction',
#   'Image Processing and Computer Vision',
#   'Computers and Education',
#   "Computer Appl. in Social and Behavioral Sciences'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Statistics, general',
#   'Artificial Intelligence',
#   'Systems and Data Security',
#   "Health Informatics'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Computer Systems Organization and Communication Networks',
#   'Software Engineering',
#   'Computer Appl. in Social and Behavioral Sciences',
#   "Numeric Computing'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Information Systems and Communication Service',
#   'Computer Appl. in Social and Behavioral Sciences',
#   "Computers and Education'"],
#  ["'Computer Science",
#   'Computer Communication Networks',
#   'Wireless and Mobile Communication',
#   "Communications Engineering, Networks'"],
#  ["'Computer Science",
#   'Image Processing and Computer Vision',
#   'Pattern Recognition',
#   "Health Informatics'"],
#  ["'Engineering", "Automotive Engineering'"],
#  ["'Business and Management",
#   'Health Care Management',
#   'Public Health',
#   "Artificial Intelligence'"],
#  ["'Computer Science", "Information Systems and Communication Service'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   "Software Engineering/Programming and Operating Systems'"],
#  ["'Engineering", "Mathematical and Computational Engineering'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Mathematical Applications in the Physical Sciences',
#   "Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'Computer Science, general',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Business and Management",
#   'Production',
#   'Manufacturing, Machines, Tools, Processes',
#   "Control, Robotics, Mechatronics'"],
#  ["'Computer Science",
#   'Computer Systems Organization and Communication Networks',
#   "Computer Hardware'"],
#  ["'Computer Science",
#   'Programming Languages, Compilers, Interpreters',
#   'Processor Architectures',
#   "Computer Science, general'"],
#  ["'Engineering",
#   'Control, Robotics, Mechatronics',
#   'Artificial Intelligence',
#   'User Interfaces and Human Computer Interaction',
#   'Vibration, Dynamical Systems, Control',
#   "Robotics and Automation'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Information Systems and Communication Service',
#   'Computer Communication Networks',
#   "Signal,Image and Speech Processing'"],
#  ["'Computer Science",
#   'Computer Science, general',
#   'Computer Systems Organization and Communication Networks',
#   'Software Engineering/Programming and Operating Systems',
#   'Data Structures and Information Theory',
#   'Information Systems and Communication Service',
#   "Computer Imaging, Vision, Pattern Recognition and Graphics'"],
#  ["'Engineering",
#   'Engineering, general',
#   'Computer Science, general',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Engineering",
#   'Mechanical Engineering',
#   'Nanotechnology',
#   'Tribology, Corrosion and Coatings',
#   'Physical Chemistry',
#   "Surfaces and Interfaces, Thin Films'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Computer Science",
#   'Computer Graphics',
#   'User Interfaces and Human Computer Interaction',
#   'Artificial Intelligence',
#   "Image Processing and Computer Vision'"],
#  ["'Environment", 'Soil Science & Conservation', "Ecology'"],
#  ["'Engineering",
#   'Mechanical Engineering',
#   'Nanotechnology',
#   'Tribology, Corrosion and Coatings',
#   'Physical Chemistry',
#   "Surfaces and Interfaces, Thin Films'"],
#  ["'Engineering",
#   'Engineering Fluid Dynamics',
#   'Fluid- and Aerodynamics',
#   "Environmental Engineering/Biotechnology'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   "Vibration, Dynamical Systems, Control'"],
#  ["'Environment", 'Soil Science & Conservation', "Ecology'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Earth Sciences",
#   'Atmospheric Sciences',
#   'Meteorology',
#   "Geophysics/Geodesy'"],
#  ["'Earth Sciences",
#   'Atmospheric Sciences',
#   'Meteorology',
#   "Geophysics/Geodesy'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Earth Sciences",
#   'Atmospheric Sciences',
#   'Meteorology',
#   "Geophysics/Geodesy'"],
#  ["'Earth Sciences",
#   'Atmospheric Sciences',
#   'Meteorology',
#   "Geophysics/Geodesy'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Earth Sciences",
#   'Atmospheric Sciences',
#   'Meteorology',
#   "Geophysics/Geodesy'"],
#  ["'Earth Sciences",
#   'Atmospheric Sciences',
#   'Meteorology',
#   "Geophysics/Geodesy'"],
#  ["'Engineering",
#   'Mechanical Engineering',
#   'Nanotechnology',
#   'Tribology, Corrosion and Coatings',
#   'Physical Chemistry',
#   "Surfaces and Interfaces, Thin Films'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Engineering",
#   'Building Construction and Design',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Atmospheric Protection/Air Quality Control/Air Pollution',
#   "Monitoring/Environmental Analysis'"],
#  ["'Engineering",
#   'Mechanical Engineering',
#   'Nanotechnology',
#   'Tribology, Corrosion and Coatings',
#   'Physical Chemistry',
#   "Surfaces and Interfaces, Thin Films'"],
#  ["'Engineering",
#   'Mechanical Engineering',
#   'Nanotechnology',
#   'Tribology, Corrosion and Coatings',
#   'Physical Chemistry',
#   "Surfaces and Interfaces, Thin Films'"],
#  ["'Business and Management",
#   'IT in Business',
#   'Software Management',
#   'Risk Management',
#   "Systems and Data Security'"],
#  ["'Engineering",
#   'Electronics and Microelectronics, Instrumentation',
#   'Circuits and Systems',
#   'Processor Architectures',
#   'Control Structures and Microprogramming',
#   "Logic Design'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Biomedical Engineering and Bioengineering',
#   "Health Informatics'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Health Informatics',
#   'Cancer Research',
#   'Genetics and Genomics',
#   "Bioinformatics'"],
#  ["'Mathematics",
#   'Systems Theory, Control',
#   'Control and Systems Theory',
#   "Optimization'"],
#  ["'Business and Management",
#   'IT in Business',
#   'Software Management',
#   'Risk Management',
#   "Systems and Data Security'"],
#  ["'Engineering",
#   'Electronics and Microelectronics, Instrumentation',
#   'Circuits and Systems',
#   'Processor Architectures',
#   'Control Structures and Microprogramming',
#   "Logic Design'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Mechanical Engineering',
#   'Engineering Acoustics',
#   "Signal, Image and Speech Processing'"],
#  ["'Mathematics",
#   'Systems Theory, Control',
#   'Control and Systems Theory',
#   "Optimization'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Health Informatics',
#   'Cancer Research',
#   'Genetics and Genomics',
#   "Bioinformatics'"],
#  ["'Engineering",
#   'Biomedical Engineering and Bioengineering',
#   'Dentistry',
#   'Artificial Intelligence',
#   "Machine Learning'"],
#  ["'Business and Management",
#   'IT in Business',
#   'Software Management',
#   'Risk Management',
#   "Systems and Data Security'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Health Informatics',
#   'Cancer Research',
#   'Genetics and Genomics',
#   "Bioinformatics'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Wireless and Mobile Communication',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Mathematics",
#   'Systems Theory, Control',
#   'Control and Systems Theory',
#   "Optimization'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Law",
#   'Private International Law, International & Foreign Law, Comparative Law',
#   'IT Law, Media Law, Intellectual Property',
#   'Artificial Intelligence',
#   'Online Marketing/Social Media',
#   'Big Data',
#   "International Economic Law, Trade Law'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Machine Learning',
#   "Artificial Intelligence'"],
#  ["'Computer Science", 'Machine Learning', 'Privacy', "Cryptology'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Health Informatics',
#   'Cancer Research',
#   'Genetics and Genomics',
#   "Bioinformatics'"],
#  ["'Engineering",
#   'Microwaves, RF and Optical Engineering',
#   'Wireless and Mobile Communication',
#   "Optics, Lasers, Photonics, Optical Devices'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering", "Circuits and Systems'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   "Data Engineering'"],
#  ["'Law",
#   'Private International Law, International & Foreign Law, Comparative Law',
#   'IT Law, Media Law, Intellectual Property',
#   'Artificial Intelligence',
#   'Online Marketing/Social Media',
#   'Big Data',
#   "International Economic Law, Trade Law'"],
#  ["'Computer Science", "Artificial Intelligence'"],
#  ["'Engineering", "Automotive Engineering'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Control, Robotics, Mechatronics',
#   'Computational Intelligence',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Signal, Image and Speech Processing',
#   'Communications Engineering, Networks',
#   "Artificial Intelligence'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Industrial and Production Engineering',
#   'Computer Communication Networks',
#   'Electrical Engineering',
#   "Mathematical Modeling and Industrial Mathematics'"],
#  ["'Engineering",
#   'Industrial and Production Engineering',
#   'Machinery and Machine Elements',
#   "Materials Engineering'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Computer Science", "Artificial Intelligence'"],
#  ["'Computer Science", "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Health Informatics',
#   'Cancer Research',
#   'Genetics and Genomics',
#   "Bioinformatics'"],
#  ["'Engineering",
#   'Mechanical Engineering',
#   'Engineering Acoustics',
#   "Signal, Image and Speech Processing'"],
#  ["'Engineering",
#   'Biomedical Engineering and Bioengineering',
#   'Artificial Intelligence',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   'Biological and Medical Physics, Biophysics',
#   "Information Storage and Retrieval'"],
#  ["'Law",
#   'Private International Law, International & Foreign Law, Comparative Law',
#   'IT Law, Media Law, Intellectual Property',
#   'Artificial Intelligence',
#   'Online Marketing/Social Media',
#   'Big Data',
#   "International Economic Law, Trade Law'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   "Machine Learning'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Signal, Image and Speech Processing',
#   'Communications Engineering, Networks',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   "Data Engineering'"],
#  ["'Mathematics",
# ...
#   'Communications Engineering, Networks',
#   'Artificial Intelligence',
#   'Computational Intelligence',
#   "Bioinformatics'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Data Engineering',
#   "Management'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Computational Intelligence',
#   "Wireless and Mobile Communication'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Computational Intelligence',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Computer Science",
#   'Systems and Data Security',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Mobile and Network Security',
#   'Artificial Intelligence',
#   "Big Data'"],
#  ["'Chemistry", 'Mass Spectrometry', "Cell Biology'"],
#  ["'Engineering",
#   'Circuits and Systems',
#   "Microwaves, RF and Optical Engineering'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   "Industrial and Production Engineering'"],
#  ["'Engineering",
#   'Engineering Design',
#   'Industrial and Production Engineering',
#   "Computer-Aided Engineering (CAD, CAE) and Design'"],
#  ["'Engineering",
#   'Wireless and Mobile Communication',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   "Communications Engineering, Networks'"],
#  ["'Engineering",
#   'Electrical Engineering',
#   'Biomedical Engineering and Bioengineering',
#   "Computer Systems Organization and Communication Networks'"],
#  ["'Engineering",
#   'Biomedical Engineering and Bioengineering',
#   'Artificial Intelligence',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   'Biological and Medical Physics, Biophysics',
#   "Information Storage and Retrieval'"],
#  ["'Engineering", 'Control and Systems Theory', "Computational Intelligence'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Wireless and Mobile Communication',
#   'Signal, Image and Speech Processing',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Communications Engineering, Networks',
#   'Science and Technology Studies',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   'Computational Intelligence',
#   "Security Science and Technology'"],
#  ["'Engineering",
#   'Cyber-physical systems, IoT',
#   'Data Engineering',
#   'Computational Intelligence',
#   'Big Data',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Industrial and Production Engineering',
#   'Mechatronics',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Energy Storage',
#   "Materials Engineering'"],
#  ["'Engineering",
#   'Wireless and Mobile Communication',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   "Communications Engineering, Networks'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Control, Robotics, Mechatronics',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Wireless and Mobile Communication',
#   "Statistics, general'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Cognitive Psychology',
#   'Personality and Social Psychology',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Data Engineering',
#   'Computational Intelligence',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Cognitive Psychology',
#   'Personality and Social Psychology',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Statistics, general',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   "Communications Engineering, Networks'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Signal, Image and Speech Processing',
#   'Communications Engineering, Networks',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Control, Robotics, Mechatronics',
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Data Structures and Information Theory',
#   "Mobile and Network Security'"],
#  ["'Engineering", 'Computational Intelligence', "Data Engineering'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Signal, Image and Speech Processing',
#   'Mobile and Network Security',
#   "Artificial Intelligence'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Data Engineering',
#   'Data Mining and Knowledge Discovery',
#   "Computer Imaging, Vision, Pattern Recognition and Graphics'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Control, Robotics, Mechatronics',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Wireless and Mobile Communication',
#   "Statistics, general'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Communications Engineering, Networks',
#   "Mobile and Network Security'"],
#  ["'Life Sciences", 'Cell Biology', "Bioinformatics'"],
#  ["'Computer Science",
#   'Artificial Intelligence',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Sociology, general',
#   'Computational Intelligence',
#   "Machine Learning'"],
#  ["'Engineering",
#   'Industrial and Production Engineering',
#   'Mechatronics',
#   'Engineering Thermodynamics, Heat and Mass Transfer',
#   'Energy Storage',
#   "Materials Engineering'"],
#  ["'Engineering",
#   'Control, Robotics, Mechatronics',
#   'Robotics',
#   "Computational Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Cognitive Psychology',
#   'Personality and Social Psychology',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Computational Intelligence',
#   'Statistics, general',
#   "Mobile and Network Security'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Wireless and Mobile Communication',
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Data Engineering',
#   "Computer Systems Organization and Communication Networks'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   "Communications Engineering, Networks'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Data Engineering',
#   "Management'"],
#  ["'Engineering",
#   'Automotive Engineering',
#   'Artificial Intelligence',
#   "Transportation Technology and Traffic Engineering'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Machine Learning',
#   "Artificial Intelligence'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Computer Systems Organization and Communication Networks',
#   "Statistics, general'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Control, Robotics, Mechatronics',
#   'Computational Intelligence',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Signal, Image and Speech Processing',
#   'Computational Intelligence',
#   'Multiagent Systems',
#   "Systems Theory, Control'"],
#  ["'Engineering",
#   'Aerospace Technology and Astronautics',
#   'Engine Technology',
#   'Automotive Engineering',
#   "Mechanical Engineering'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Signal, Image and Speech Processing',
#   'Computational Intelligence',
#   'Multiagent Systems',
#   "Systems Theory, Control'"],
#  ["'Computer Science", "Artificial Intelligence'"],
#  ["'Engineering",
#   'Industrial and Production Engineering',
#   'Surfaces and Interfaces, Thin Films',
#   "Energy Systems'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   "Data Structures and Information Theory'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   "Communications Engineering, Networks'"],
#  ["'Engineering",
#   'Wireless and Mobile Communication',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   "Communications Engineering, Networks'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering", 'Data Engineering', "Computational Intelligence'"],
#  ["'Engineering",
#   'Data Engineering',
#   'Statistics, general',
#   'Machine Learning',
#   'Artificial Intelligence',
#   'Data Storage Representation',
#   "Data Structures and Information Theory'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Control, Robotics, Mechatronics',
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Data Structures and Information Theory',
#   "Mobile and Network Security'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Computational Intelligence',
#   'Statistics, general',
#   "Mobile and Network Security'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Information Storage and Retrieval',
#   'Computer Imaging, Vision, Pattern Recognition and Graphics',
#   'Data Structures and Information Theory',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Control, Robotics, Mechatronics',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   "Transportation Technology and Traffic Engineering'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering",
#   'Control, Robotics, Mechatronics',
#   'Energy Systems',
#   "Computational Intelligence'"],
#  ["'Engineering",
#   'Electronics and Microelectronics, Instrumentation',
#   "Engineering Mathematics'"],
#  ["'Mathematics",
#   'Applications of Mathematics',
#   'Statistics for Business, Management, Economics, Finance, Insurance',
#   'Machine Learning',
#   'Data Structures and Information Theory',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Machine Learning',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Communications Engineering, Networks',
#   "Mobile and Network Security'"],
#  ["'Engineering", 'Engineering Mathematics', "Computational Intelligence'"],
#  ["'Engineering",
#   'Signal, Image and Speech Processing',
#   'Computational Intelligence',
#   'Multiagent Systems',
#   "Systems Theory, Control'"],
#  ["'Engineering", 'Computational Intelligence', "Data Engineering'"],
#  ["'Engineering",
#   'Robotics and Automation',
#   'Artificial Intelligence',
#   'Industrial and Production Engineering',
#   'Professional Computing',
#   'Robotics',
#   "Machine Learning'"],
#  ["'Engineering",
#   'Signal, Image and Speech Processing',
#   'Computational Intelligence',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Machine Learning',
#   'Python',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   "Computational Intelligence'"],
#  ["'Engineering",
#   'Robotics and Automation',
#   'Artificial Intelligence',
#   'Industrial and Production Engineering',
#   'Professional Computing',
#   'Robotics',
#   "Machine Learning'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Signal, Image and Speech Processing',
#   'Mobile and Network Security',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Transportation Technology and Traffic Engineering',
#   'Computational Intelligence',
#   'Automotive Engineering',
#   'Energy Policy, Economics and Management',
#   "Mechanical Engineering'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Science and Technology Studies',
#   'Statistics, general',
#   'Computational Intelligence',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Machine Learning',
#   "Artificial Intelligence'"],
#  ["'Chemistry",
#   'Analytical Chemistry',
#   'Mass Spectrometry',
#   'Materials Science, general',
#   'Spectroscopy/Spectrometry',
#   "Medicinal Chemistry'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Machine Learning',
#   'Big Data',
#   "Computer Systems Organization and Communication Networks'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Machine Learning',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Sustainable Development',
#   'Artificial Intelligence',
#   'Data Structures and Information Theory',
#   "Machine Learning'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Communications Engineering, Networks',
#   "Mobile and Network Security'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Cognitive Psychology',
#   'Personality and Social Psychology',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Science and Technology Studies',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Computational Intelligence',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Circuits and Systems',
#   'Artificial Intelligence',
#   'Mathematics, general',
#   'Special Purpose and Application-Based Systems',
#   "Computer Science, general'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Engineering", 'Computational Intelligence', "Data Engineering'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Science and Technology Studies',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Computational Intelligence',
#   "Artificial Intelligence'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Communications Engineering, Networks',
#   'Science and Technology Studies',
#   'Cyber-physical systems, IoT',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Data Engineering',
#   "Management'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Cyber-physical systems, IoT',
#   'Professional Computing',
#   'Machine Learning',
#   "Artificial Intelligence'"],
#  ["'Computer Science",
#   'Data Structures and Information Theory',
#   'Artificial Intelligence',
#   'Machine Learning',
#   'Natural Language Processing (NLP)',
#   'Knowledge based Systems',
#   "Business Information Systems'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Systems and Data Security',
#   'Artificial Intelligence',
#   "Computer Imaging, Vision, Pattern Recognition and Graphics'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Statistics, general',
#   'Cyber-physical systems, IoT',
#   'Sociology, general',
#   "Professional Computing'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Systems and Data Security',
#   'Artificial Intelligence',
#   "Computer Imaging, Vision, Pattern Recognition and Graphics'"],
#  ["'Engineering", 'Computational Intelligence', "Artificial Intelligence'"],
#  ["'Business and Management", "Organization'"],
#  ["'Engineering",
#   'Control and Systems Theory',
#   'Control, Robotics, Mechatronics',
#   "Communications Engineering, Networks'"],
#  ["'Engineering",
#   'Computational Intelligence',
#   'Artificial Intelligence',
#   'Systems and Data Security',
#   "Mobile and Network Security'"],
#  ["'Engineering",
#   'Communications Engineering, Networks',
#   'Control, Robotics, Mechatronics',
#   'Computational Intelligence',
#   "Artificial Intelligence'"],
#  ...]

# %%
flat_list = [item.replace("'","") for sublist in areas for item in sublist]

# %%
flat_list
# Out:
# ['Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Professional Computing',
#  'Engineering',
#  'Computational Intelligence',
#  'Control, Robotics, Mechatronics',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Computer Systems Organization and Communication Networks',
#  'Communications Engineering, Networks',
#  'Wireless and Mobile Communication',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Graph Theory',
#  'Operations Research, Management Science',
#  'Theory of Computation',
#  'Algorithm Analysis and Problem Complexity',
#  'Economics',
#  'Health Economics',
#  'Pharmaceutical Sciences/Technology',
#  'Economics, general',
#  'Biomedicine, general',
#  'Biotechnology',
#  'Economic Theory/Quantitative Economics/Mathematical Methods',
#  'Engineering',
#  'Computational Intelligence',
#  'Control, Robotics, Mechatronics',
#  'Artificial Intelligence',
#  'Engineering',
#  'Data Engineering',
#  'Statistics, general',
#  'Machine Learning',
#  'Artificial Intelligence',
#  'Data Storage Representation',
#  'Data Structures and Information Theory',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Machine Learning',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Cyber-physical systems, IoT',
#  'Computer Communication Networks',
#  'Engineering',
#  'Computational Intelligence',
#  'Data Engineering',
#  'Engineering',
#  'Computational Intelligence',
#  'Control, Robotics, Mechatronics',
#  'Artificial Intelligence',
#  'Engineering',
#  'Computational Intelligence',
#  'Signal, Image and Speech Processing',
#  'Communications Engineering, Networks',
#  'Artificial Intelligence',
#  'Engineering',
#  'Cyber-physical systems, IoT',
#  'Communications Engineering, Networks',
#  'Computer Applications',
#  'Computer Science',
#  'Computer Communication Networks',
#  'Special Purpose and Application-Based Systems',
#  'Information Systems Applications (incl.Internet)',
#  'Computer Systems Organization and Communication Networks',
#  'Computer System Implementation',
#  'Software Engineering/Programming and Operating Systems',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Robotics and Automation',
#  'User Interfaces and Human Computer Interaction',
#  'Engineering',
#  'Electrical Engineering',
#  'Automotive Engineering',
#  'Robotics and Automation',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Civil Engineering',
#  'User Interfaces and Human Computer Interaction',
#  'Computer Science',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Artificial Intelligence',
#  'Image Processing and Computer Vision',
#  'Pattern Recognition',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Computer Science',
#  'Processor Architectures',
#  'Operating Systems',
#  'Computer Communication Networks',
#  'Engineering',
#  'Electrical Engineering',
#  'Automotive Engineering',
#  'Robotics and Automation',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Civil Engineering',
#  'User Interfaces and Human Computer Interaction',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Control, Robotics, Mechatronics',
#  'User Interfaces and Human Computer Interaction',
#  'Manufacturing, Machines, Tools, Processes',
#  'Electronics and Microelectronics, Instrumentation',
#  'Computer Science',
#  'Processor Architectures',
#  'Operating Systems',
#  'Computer Communication Networks',
#  'Computer Science',
#  'Processor Architectures',
#  'Operating Systems',
#  'Computer Communication Networks',
#  'Computer Science',
#  'Computer Communication Networks',
#  'Special Purpose and Application-Based Systems',
#  'Information Systems Applications (incl.Internet)',
#  'Computer Systems Organization and Communication Networks',
#  'Computer System Implementation',
#  'Software Engineering/Programming and Operating Systems',
#  'Computer Science',
#  'Programming Languages, Compilers, Interpreters',
#  'Processor Architectures',
#  'Computer Science, general',
#  'Engineering',
#  'Robotics and Automation',
#  'Artificial Intelligence',
#  'Control and Systems Theory',
#  'Machine Learning',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Engineering',
#  'Aerospace Technology and Astronautics',
#  'Mathematical Applications in the Physical Sciences',
#  'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#  'Computer Science',
#  'Computer Communication Networks',
#  'Special Purpose and Application-Based Systems',
#  'Information Systems Applications (incl.Internet)',
#  'Computer Systems Organization and Communication Networks',
#  'Computer System Implementation',
#  'Software Engineering/Programming and Operating Systems',
#  'Computer Science',
#  'Programming Languages, Compilers, Interpreters',
#  'Processor Architectures',
#  'Computer Science, general',
#  'Science, Humanities and Social Sciences, multidisciplinary',
#  'Science, Humanities and Social Sciences, multidisciplinary',
#  'Science, multidisciplinary',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Machine Learning',
#  'Control, Robotics, Mechatronics',
#  'Artificial Intelligence',
#  'Simulation and Modeling',
#  'Natural Language Processing (NLP)',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Robotics and Automation',
#  'User Interfaces and Human Computer Interaction',
#  'Computer Science',
#  'Programming Languages, Compilers, Interpreters',
#  'Processor Architectures',
#  'Computer Science, general',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Science, general',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Science, general',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Information Systems Applications (incl.Internet)',
#  'Database Management',
#  'Operating Systems',
#  'Computer Science',
#  'Programming Languages, Compilers, Interpreters',
#  'Processor Architectures',
#  'Computer Science, general',
#  'Physics',
#  'Particle and Nuclear Physics',
#  'Particle Acceleration and Detection, Beam Physics',
#  'Nuclear Energy',
#  'Science, Humanities and Social Sciences, multidisciplinary',
#  'Science, Humanities and Social Sciences, multidisciplinary',
#  'Science, multidisciplinary',
#  'Engineering',
#  'Industrial and Production Engineering',
#  'Media Management',
#  'Mechanical Engineering',
#  'Computer-Aided Engineering (CAD, CAE) and Design',
#  'Engineering',
#  'Computational Intelligence',
#  'Complexity',
#  'Data Structures and Information Theory',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Science, general',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Complex Systems',
#  'Computational Intelligence',
#  'Computer Science',
#  'Processor Architectures',
#  'Operating Systems',
#  'Computer Communication Networks',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Life Sciences',
#  'Bioinformatics',
#  'Microarrays',
#  'Computational Biology/Bioinformatics',
#  'Computer Appl. in Life Sciences',
#  'Algorithms',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Control, Robotics, Mechatronics',
#  'Complex Systems',
#  'Systems Biology',
#  'Pattern Recognition',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Programming Languages, Compilers, Interpreters',
#  'Processor Architectures',
#  'Computer Science, general',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Control, Robotics, Mechatronics',
#  'Complex Systems',
#  'Systems Biology',
#  'Pattern Recognition',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Computer Science',
#  'Programming Languages, Compilers, Interpreters',
#  'Processor Architectures',
#  'Computer Science, general',
#  'Psychology',
#  'Psychology, general',
#  'Sociology, general',
#  'Anthropology',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Computer Science',
#  'Programming Languages, Compilers, Interpreters',
#  'Processor Architectures',
#  'Computer Science, general',
#  'Business and Management',
#  'Production',
#  'Manufacturing, Machines, Tools, Processes',
#  'Control, Robotics, Mechatronics',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Computer Communication Networks',
#  'Electrical Engineering',
#  'IT in Business',
#  'Computer Science',
#  'Programming Languages, Compilers, Interpreters',
#  'Processor Architectures',
#  'Computer Science, general',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Computer Science',
#  'Software Engineering/Programming and Operating Systems',
#  'Programming Languages, Compilers, Interpreters',
#  'Business and Management',
#  'IT in Business',
#  'Management of Computing and Information Systems',
#  'Systems Theory, Control',
#  'Operations Research/Decision Theory',
#  'Physics',
#  'Particle and Nuclear Physics',
#  'Particle Acceleration and Detection, Beam Physics',
#  'Nuclear Energy',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Science, general',
#  'Engineering',
#  'Mathematical and Computational Engineering',
#  'Artificial Intelligence',
#  'Statistical Physics and Dynamical Systems',
#  'Control, Robotics, Mechatronics',
#  'Bioinformatics',
#  'Applications of Mathematics',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Robotics and Automation',
#  'User Interfaces and Human Computer Interaction',
#  'Computer Science',
#  'Computer Communication Networks',
#  'Computer Systems Organization and Communication Networks',
#  'Communications Engineering, Networks',
#  'Information Systems and Communication Service',
#  'Operations Research/Decision Theory',
#  'Computer Science',
#  'Computer Science, general',
#  'Information Systems Applications (incl.Internet)',
#  'Computer Communication Networks',
#  'Software Engineering',
#  'Artificial Intelligence',
#  'Computer Appl. in Administrative Data Processing',
#  'Environment',
#  'Sustainable Development',
#  'Environmental Management',
#  'Environmental Economics',
#  'Ecology',
#  'Economic Growth',
#  'Economic Geology',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Operations Research, Management Science',
#  'Business and Management',
#  'Operations Research/Decision Theory',
#  'Combinatorics',
#  'Theory of Computation',
#  'Engineering',
#  'Signal,Image and Speech Processing',
#  'Communications Engineering, Networks',
#  'Information Systems Applications (incl.Internet)',
#  'Engineering',
#  'Robotics and Automation',
#  'Artificial Intelligence',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Control, Robotics, Mechatronics',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Multimedia Information Systems',
#  'Computer Communication Networks',
#  'Data Structures and Information Theory',
#  'Special Purpose and Application-Based Systems',
#  'Engineering',
#  'Robotics and Automation',
#  'Artificial Intelligence',
#  'Control and Systems Theory',
#  'Machine Learning',
#  'Computer Science',
#  'Processor Architectures',
#  'Management of Computing and Information Systems',
#  'User Interfaces and Human Computer Interaction',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Manufacturing, Machines, Tools, Processes',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Science, general',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Science, general',
#  'Engineering',
#  'Computational Intelligence',
#  'Complexity',
#  'Data Structures and Information Theory',
#  'Computer Science',
#  'Cryptology',
#  'Computer Communication Networks',
#  'Operating Systems',
#  'Coding and Information Theory',
#  'Management of Computing and Information Systems',
#  'Communications Engineering, Networks',
#  'Computer Science',
#  'Computer Communication Networks',
#  'Computer Systems Organization and Communication Networks',
#  'Communications Engineering, Networks',
#  'Information Systems and Communication Service',
#  'Operations Research/Decision Theory',
#  'Engineering',
#  'Robotics and Automation',
#  'Artificial Intelligence',
#  'Control and Systems Theory',
#  'Machine Learning',
#  'Business and Management',
#  'Operations Research/Decision Theory',
#  'Combinatorics',
#  'Theory of Computation',
#  'Science, Humanities and Social Sciences, multidisciplinary',
#  'Science, Humanities and Social Sciences, multidisciplinary',
#  'Science, multidisciplinary',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Information Systems and Communication Service',
#  'Computer Communication Networks',
#  'Signal,Image and Speech Processing',
#  'Engineering',
#  'Engineering, general',
#  'Business and Management',
#  'Operations Research/Decision Theory',
#  'Combinatorics',
#  'Theory of Computation',
#  'Engineering',
#  'Control, Robotics, Mechatronics',
#  'Electrical Engineering',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Business and Management',
#  'Production',
#  'Manufacturing, Machines, Tools, Processes',
#  'Control, Robotics, Mechatronics',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Psychology',
#  'Cognitive Psychology',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Mining and Knowledge Discovery',
#  'Probability and Statistics in Computer Science',
#  'Computational Science and Engineering',
#  'Image Processing and Computer Vision',
#  'Computational Biology/Bioinformatics',
#  'Science, Humanities and Social Sciences, multidisciplinary',
#  'Science, Humanities and Social Sciences, multidisciplinary',
#  'Science, multidisciplinary',
#  'Engineering',
#  'Computational Intelligence',
#  'Communications Engineering, Networks',
#  'Artificial Intelligence',
#  'Science and Technology Studies',
#  'Computer Applications',
#  'Computer Science',
#  'Machine Learning',
#  'Artificial Intelligence',
#  'Computer Science, general',
#  'Engineering',
#  'Computational Intelligence',
#  'Machine Learning',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Machine Learning',
#  'Engineering',
#  'Computational Intelligence',
#  'Control, Robotics, Mechatronics',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Machine Learning',
#  'Java',
#  'Data Mining and Knowledge Discovery',
#  'Engineering',
#  'Computational Intelligence',
#  'Control, Robotics, Mechatronics',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Computers and Education',
#  'Computer Applications',
#  'Computer Science',
#  'Computer Applications',
#  'Data Mining and Knowledge Discovery',
#  'IT in Business',
#  'Machine Learning',
#  'Computer Science',
#  'Data Mining and Knowledge Discovery',
#  'Artificial Intelligence',
#  'Information Systems Applications (incl. Internet)',
#  'Database Management',
#  'Computer Appl. in Social and Behavioral Sciences',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Engineering',
#  'Mathematical and Computational Engineering',
#  'Mechanical Engineering',
#  'Electrical Engineering',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computing Milieux',
#  'Information Systems and Communication Service',
#  'Computer Applications',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Engineering',
#  'Wireless and Mobile Communication',
#  'Artificial Intelligence',
#  'Computer Applications',
#  'Computing Milieux',
#  'Computer Communication Networks',
#  'Computer Science',
#  'Computer Applications',
#  'Cryptology',
#  'Mobile and Network Security',
#  'Computer Crime',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Information Systems and Communication Service',
#  'Computer Applications',
#  'Computers and Education',
#  'Computer Systems Organization and Communication Networks',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Engineering',
#  'Control, Robotics, Mechatronics',
#  'Computational Intelligence',
#  'Communications Engineering, Networks',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Applications',
#  'Data Mining and Knowledge Discovery',
#  'Image Processing and Computer Vision',
#  'Computer Science',
#  'Computer Applications',
#  'Artificial Intelligence',
#  'Systems and Data Security',
#  'Computers and Education',
#  'Computer Science',
#  'Computer Communication Networks',
#  'Wireless and Mobile Communication',
#  'Communications Engineering, Networks',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Structures and Information Theory',
#  'Software Engineering/Programming and Operating Systems',
#  'Information Systems and Communication Service',
#  'Computer Communication Networks',
#  'Computer Science',
#  'Mathematical Logic and Formal Languages',
#  'Software Engineering/Programming and Operating Systems',
#  'Information Systems and Communication Service',
#  'Artificial Intelligence',
#  'Logics and Meanings of Programs',
#  'Computer Science',
#  'Computer Science, general',
#  'Electrical Engineering',
#  'Computer Hardware',
#  'Computer Systems Organization and Communication Networks',
#  'Electronics and Microelectronics, Instrumentation',
#  'Communications Engineering, Networks',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Computational Intelligence',
#  'Computer Communication Networks',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Information Systems and Communication Service',
#  'Computing Milieux',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Computer Applications',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Software Engineering',
#  'Information Systems Applications (incl. Internet)',
#  'User Interfaces and Human Computer Interaction',
#  'Computer Communication Networks',
#  'Special Purpose and Application-Based Systems',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Communication Networks',
#  'Data Mining and Knowledge Discovery',
#  'Information Systems Applications (incl. Internet)',
#  'Image Processing and Computer Vision',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Computational Intelligence',
#  'Computer Communication Networks',
#  'Artificial Intelligence',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Mathematical Logic and Foundations',
#  'Control, Robotics, Mechatronics',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Theory of Computation',
#  'Computer Communication Networks',
#  'Computing Milieux',
#  'Special Purpose and Application-Based Systems',
#  'Software Engineering/Programming and Operating Systems',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Theory of Computation',
#  'Mathematics of Computing',
#  'Information Systems and Communication Service',
#  'Machine Learning',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Cyber-physical systems, IoT',
#  'Professional Computing',
#  'Computer Science',
#  'Computers and Society',
#  'Information Systems and Communication Service',
#  'Artificial Intelligence',
#  'Computer Communication Networks',
#  'Computer System Implementation',
#  'Special Purpose and Application-Based Systems',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Data Structures and Information Theory',
#  'Information Systems Applications (incl. Internet)',
#  'Theory of Computation',
#  'Computer Appl. in Administrative Data Processing',
#  'Computer Appl. in Social and Behavioral Sciences',
#  'Computer Science',
#  'Special Purpose and Application-Based Systems',
#  'Computer Communication Networks',
#  'Computer Applications',
#  'Computer System Implementation',
#  'Mathematics',
#  'Mathematical Applications in Computer Science',
#  'Data Structures and Information Theory',
#  'Discrete Mathematics in Computer Science',
#  'Numerical Analysis',
#  'Algorithms',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Computers and Education',
#  'Computer Applications',
#  'Computer Science',
#  'Mathematics of Computing',
#  'Artificial Intelligence',
#  'Theory of Computation',
#  'Information Systems and Communication Service',
#  'Computer Systems Organization and Communication Networks',
#  'Computer Science',
#  'Computer Systems Organization and Communication Networks',
#  'Information Systems and Communication Service',
#  'Artificial Intelligence',
#  'Computer Appl. in Social and Behavioral Sciences',
#  'Computers and Education',
#  'Engineering',
#  'Cyber-physical systems, IoT',
#  'Communications Engineering, Networks',
#  'Automotive Engineering',
#  'Computer Science',
#  'Professional Computing',
#  'Algorithm Analysis and Problem Complexity',
#  'Computer Systems Organization and Communication Networks',
#  'Software Engineering/Programming and Operating Systems',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computational Intelligence',
#  'Computer Applications',
#  'Machine Learning',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Information Systems and Communication Service',
#  'Computer Systems Organization and Communication Networks',
#  'Computer Appl. in Social and Behavioral Sciences',
#  'Engineering',
#  'Control, Robotics, Mechatronics',
#  'Transportation Technology and Traffic Engineering',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Machine Learning',
#  'Systems and Data Security',
#  'Mobile and Network Security',
#  'Security Science and Technology',
#  'Engineering',
#  'Data Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Engineering',
#  'Cyber-physical systems, IoT',
#  'Professional Computing',
#  'Wireless and Mobile Communication',
#  'Mobile and Network Security',
#  'Computer Science',
#  'Image Processing and Computer Vision',
#  'User Interfaces and Human Computer Interaction',
#  'Computer Appl. in Social and Behavioral Sciences',
#  'Pattern Recognition',
#  'Machine Learning',
#  'Robotics',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Cyber-physical systems, IoT',
#  'Professional Computing',
#  'Engineering',
#  'Transportation Technology and Traffic Engineering',
#  'Mechanical Engineering',
#  'User Interfaces and Human Computer Interaction',
#  'Complexity',
#  'Computer Science',
#  'Computer Systems Organization and Communication Networks',
#  'Computer System Implementation',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Computer Applications',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Information Systems and Communication Service',
#  'Computer Communication Networks',
#  'Signal,Image and Speech Processing',
#  'Computer Science',
#  'Professional Computing',
#  'Mobile Computing',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Mechanical Engineering',
#  'Artificial Intelligence',
#  'Engineering',
#  'Computational Intelligence',
#  'Control, Robotics, Mechatronics',
#  'Artificial Intelligence',
#  'Engineering',
#  'Computational Intelligence',
#  'Communications Engineering, Networks',
#  'Mobile and Network Security',
#  'Cyber-physical systems, IoT',
#  'Professional Computing',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Multimedia Information Systems',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Information Systems and Communication Service',
#  'Computer Communication Networks',
#  'Signal,Image and Speech Processing',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Information Systems Applications (incl. Internet)',
#  'User Interfaces and Human Computer Interaction',
#  'Computer Communication Networks',
#  'Special Purpose and Application-Based Systems',
#  'Computer System Implementation',
#  'Engineering',
#  'Computational Intelligence',
#  'Industrial and Production Engineering',
#  'Artificial Intelligence',
#  'Engineering',
#  'Computational Intelligence',
#  'Water, general',
#  'Environmental Management',
#  'Business and Management',
#  'IT in Business',
#  'Computer Communication Networks',
#  'Artificial Intelligence',
#  'Probability Theory and Stochastic Processes',
#  'Engineering',
#  'Data Engineering',
#  'Cyber-physical systems, IoT',
#  'Computational Intelligence',
#  'Big Data',
#  'Engineering',
#  'Computational Intelligence',
#  'Communications Engineering, Networks',
#  'Engineering',
#  'Computational Intelligence',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Database Management',
#  'User Interfaces and Human Computer Interaction',
#  'Image Processing and Computer Vision',
#  'Computers and Education',
#  'Computer Appl. in Social and Behavioral Sciences',
#  'Engineering',
#  'Computational Intelligence',
#  'Statistics, general',
#  'Artificial Intelligence',
#  'Systems and Data Security',
#  'Health Informatics',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Computer Systems Organization and Communication Networks',
#  'Software Engineering',
#  'Computer Appl. in Social and Behavioral Sciences',
#  'Numeric Computing',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Information Systems and Communication Service',
#  'Computer Appl. in Social and Behavioral Sciences',
#  'Computers and Education',
#  'Computer Science',
#  'Computer Communication Networks',
#  'Wireless and Mobile Communication',
#  'Communications Engineering, Networks',
#  'Computer Science',
#  'Image Processing and Computer Vision',
#  'Pattern Recognition',
#  'Health Informatics',
#  'Engineering',
#  'Automotive Engineering',
#  'Business and Management',
#  'Health Care Management',
#  'Public Health',
#  'Artificial Intelligence',
#  'Computer Science',
#  'Information Systems and Communication Service',
#  'Computer Science',
#  'Artificial Intelligence',
#  'Software Engineering/Programming and Operating Systems',
#  'Engineering',
#  'Mathematical and Computational Engineering',
#  'Engineering',
#  'Aerospace Technology and Astronautics',
#  'Mathematical Applications in the Physical Sciences',
#  'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#  'Computer Science',
#  'Computer Graphics',
#  'Computer Science, general',
#  'Artificial Intelligence',
#  'Image Processing and Computer Vision',
#  'Business and Management',
#  'Production',
#  'Manufacturing, Machines, Tools, Processes',
#  'Control, Robotics, Mechatronics',
#  'Computer Science',
#  'Computer Systems Organization and Communication Networks',
#  'Computer Hardware',
#  'Computer Science',
#  'Programming Languages, Compilers, Interpreters',
#  'Processor Architectures',
#  'Computer Science, general',
#  'Engineering',
#  'Control, Robotics, Mechatronics',
#  'Artificial Intelligence',
#  'User Interfaces and Human Computer Interaction',
#  'Vibration, Dynamical Systems, Control',
#  'Robotics and Automation',
#  'Engineering',
#  'Communications Engineering, Networks',
#  'Information Systems and Communication Service',
#  'Computer Communication Networks',
#  'Signal,Image and Speech Processing',
#  'Computer Science',
#  'Computer Science, general',
#  'Computer Systems Organization and Communication Networks',
#  'Software Engineering/Programming and Operating Systems',
#  'Data Structures and Information Theory',
#  'Information Systems and Communication Service',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Engineering',
#  'Engineering, general',
#  'Computer Science, general',
#  'Artificial Intelligence',
#  'Engineering',
#  'Aerospace Technology and Astronautics',
#  'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#  'Vibration, Dynamical Systems, Control',
#  'Engineering',
#  'Aerospace Technology and Astronautics',
#  'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#  'Vibration, Dynamical Systems, Control',
#  'Engineering',
#  'Aerospace Technology and Astronautics',
#  'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#  'Vibration, Dynamical Systems, Control',
#  'Engineering',
#  'Aerospace Technology and Astronautics',
#  'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#  'Vibration, Dynamical Systems, Control',
#  'Engineering',
#  'Aerospace Technology and Astronautics',
#  'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#  'Vibration, Dynamical Systems, Control',
#  'Engineering',
#  'Engineering Fluid Dynamics',
#  'Fluid- and Aerodynamics',
#  'Environmental Engineering/Biotechnology',
#  'Engineering',
#  'Aerospace Technology and Astronautics',
#  'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#  'Vibration, Dynamical Systems, Control',
#  'Engineering',
#  'Engineering Fluid Dynamics',
#  'Fluid- and Aerodynamics',
#  'Environmental Engineering/Biotechnology',
#  'Engineering',
#  'Aerospace Technology and Astronautics',
#  'Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#  'Vibration, Dynamical Systems, Control',
#  'Engineering',
#  'Engineering Fluid Dynamics',
#  'Fluid- and Aerodynamics',
#  'Environmental Engineering/Biotechnology',
#  'Engineering',
#  'Engineering Fluid Dynamics',
#  'Fluid- and Aerodynamics',
#  'Environmental Engineering/Biotechnology',
#  'Engineering',
#  'Engineering Fluid Dynamics',
#  'Fluid- and Aerodynamics',
#  'Environmental Engineering/Biotechnology',
#  'Engineering',
#  'Engineering Fluid Dynamics',
#  'Fluid- and Aerodynamics',
#  ...]

# %%
from collections import Counter
contados = Counter(flat_list)

# %%
new_list = sorted(contados, key=lambda x: -contados[x])
frec = [[x,contados[x]] for x in new_list ] 
frec
# Out:
# [['Engineering', 11417],
#  ['Artificial Intelligence', 6378],
#  ['Computational Intelligence', 5092],
#  ['Computer Science', 3967],
#  ['Communications Engineering, Networks', 2850],
#  ['Control, Robotics, Mechatronics', 2013],
#  ['Cyber-physical systems, IoT', 1907],
#  ['Professional Computing', 1483],
#  ['Mechanical Engineering', 1333],
#  ['Data Structures and Information Theory', 1181],
#  ['Medicine & Public Health', 1160],
#  ['Science, Humanities and Social Sciences, multidisciplinary', 1152],
#  ['Industrial and Production Engineering', 1092],
#  ['Machine Learning', 1084],
#  ['Computer Communication Networks', 1003],
#  ['Manufacturing, Machines, Tools, Processes', 889],
#  ['Robotics and Automation', 870],
#  ['Computer Science, general', 818],
#  ['Data Mining and Knowledge Discovery', 791],
#  ['Signal, Image and Speech Processing', 789],
#  ['Data Engineering', 736],
#  ['Control and Systems Theory', 679],
#  ['Image Processing and Computer Vision', 646],
#  ['Aerospace Technology and Astronautics', 615],
#  ['Business and Management', 608],
#  ['Computer Imaging, Vision, Pattern Recognition and Graphics', 596],
#  ['Transportation Technology and Traffic Engineering', 562],
#  ['Computational Biology/Bioinformatics', 534],
#  ['Science, multidisciplinary', 527],
#  ['Statistics, general', 525],
#  ['Life Sciences', 513],
#  ['Automotive Engineering', 507],
#  ['Multimedia Information Systems', 498],
#  ['Information Storage and Retrieval', 486],
#  ['Biomedical Engineering and Bioengineering', 475],
#  ['Electronics and Microelectronics, Instrumentation', 453],
#  ['User Interfaces and Human Computer Interaction', 444],
#  ['Wireless and Mobile Communication', 427],
#  ['Biomedicine', 421],
#  ['Special Purpose and Application-Based Systems', 418],
#  ['Computational Science and Engineering', 415],
#  ['Mathematical and Computational Engineering', 407],
#  ['Engineering Design', 395],
#  ['Computer Systems Organization and Communication Networks', 390],
#  ['Vibration, Dynamical Systems, Control', 390],
#  ['Environment, general', 386],
#  ['Engineering Economics, Organization, Logistics, Marketing', 382],
#  ['Bioinformatics', 379],
#  ['Science and Technology Studies', 379],
#  ['Mobile and Network Security', 378],
#  ['Materials Science, general', 373],
#  ['Probability and Statistics in Computer Science', 370],
#  ['Energy Systems', 368],
#  ['IT in Business', 357],
#  ['Circuits and Systems', 355],
#  ['Operations Research/Decision Theory', 354],
#  ['Building Construction and Design', 349],
#  ['Sustainable Development', 346],
#  ['Environment', 337],
#  ['Natural Language Processing (NLP)', 336],
#  ['Political Science and International Relations', 335],
#  ['Systems and Data Security', 327],
#  ['Machinery and Machine Elements', 324],
#  ['Building Repair and Maintenance', 324],
#  ['Earth Sciences', 322],
#  ['Chemistry', 321],
#  ['Information Systems Applications (incl.Internet)', 318],
#  ['Analytical Chemistry', 310],
#  ['Systems Theory, Control', 307],
#  ['Materials Engineering', 298],
#  ['Software Engineering/Programming and Operating Systems', 296],
#  ['Computer Applications', 294],
#  ['Complex Systems', 286],
#  ['Social Sciences', 279],
#  ['Electrical Engineering', 275],
#  ['Energy Policy, Economics and Management', 275],
#  ['Biomedicine, general', 272],
#  ['Computer-Aided Engineering (CAD, CAE) and Design', 272],
#  ['Neurosciences', 268],
#  ['Business and Management, general', 267],
#  ['Imaging / Radiology', 261],
#  ['Monitoring/Environmental Analysis', 260],
#  ['Psychology', 254],
#  ['Health Informatics', 253],
#  ['Power Electronics, Electrical Machines and Networks', 253],
#  ['Energy', 243],
#  ['Information Systems and Communication Service', 241],
#  ['Civil Engineering', 239],
#  ['Sociology, general', 238],
#  ['Complexity', 236],
#  ['Database Management', 235],
#  ['Robotics', 235],
#  ['Medicine/Public Health, general', 232],
#  ['Mathematics', 230],
#  ['Public Policy', 228],
#  ['Signal,Image and Speech Processing', 223],
#  ['Materials Science', 222],
#  ['Operating Systems', 219],
#  ['Education, general', 218],
#  ['Geotechnical Engineering & Applied Earth Sciences', 215],
#  ['Processor Architectures', 212],
#  ['Engineering, general', 212],
#  ['Structural Materials', 207],
#  ['Pattern Recognition', 205],
#  ['Engine Technology', 199],
#  ['Simulation and Modeling', 196],
#  ['Nanotechnology', 196],
#  ['Industrial and Organizational Psychology', 196],
#  ['Agriculture', 192],
#  ['Computational Mathematics and Numerical Analysis', 190],
#  ['Geoengineering, Foundations, Hydraulics', 190],
#  ['Optimization', 187],
#  ['Building Materials', 185],
#  ['Internal Medicine', 182],
#  ['Multiagent Systems', 180],
#  ['Management', 178],
#  ['Cognitive Psychology', 176],
#  ['Social Sciences, general', 174],
#  ['Education', 173],
#  ['Measurement Science and Instrumentation', 173],
#  ['Philosophy', 173],
#  ['Food Science', 170],
#  ['Waste Water Technology / Water Pollution Control / Water Management / Aquatic Pollution',
#   169],
#  ['Environmental Health', 168],
#  ['Big Data', 167],
#  ['Biological and Medical Physics, Biophysics', 167],
#  ['Physics', 166],
#  ['Atmospheric Protection/Air Quality Control/Air Pollution', 164],
#  ['Law', 164],
#  ['Geography, general', 160],
#  ['Microwaves, RF and Optical Engineering', 158],
#  ['Programming Languages, Compilers, Interpreters', 157],
#  ['Computer Graphics', 157],
#  ['Classical and Continuum Physics', 157],
#  ['Statistics for Engineering, Physics, Computer Science, Chemistry and Earth Sciences',
#   156],
#  ['Methodology of the Social Sciences', 156],
#  ['Surgery', 154],
#  ['Mathematical Logic and Foundations', 153],
#  ['Environmental Chemistry', 150],
#  ['Theory of Computation', 148],
#  ['Chemistry/Food Science, general', 145],
#  ['Management of Computing and Information Systems', 142],
#  ['Engineering Thermodynamics, Heat and Mass Transfer', 142],
#  ['Biotechnology', 140],
#  ['Computer Appl. in Social and Behavioral Sciences', 140],
#  ['Earth Sciences, general', 140],
#  ['Renewable and Green Energy', 138],
#  ['Ecotoxicology', 138],
#  ['Computers and Education', 137],
#  ['Construction Management', 137],
#  ['Public Health', 131],
#  ['Biomaterials', 129],
#  ['Economics', 128],
#  ['European Politics', 128],
#  ['Educational Technology', 128],
#  ['Ecology', 127],
#  ['Characterization and Evaluation of Materials', 126],
#  ['Criminology and Criminal Justice', 126],
#  ['Environmental Management', 125],
#  ['Private International Law, International & Foreign Law, Comparative Law',
#   123],
#  ['Space Sciences (including Extraterrestrial Physics, Space Exploration and Astronautics)',
#   122],
#  ['Algorithms', 121],
#  ['Geophysics/Geodesy', 121],
#  ['Clinical Psychology', 120],
#  ['Industrial Chemistry/Chemical Engineering', 119],
#  ['Engineering Fluid Dynamics', 118],
#  ['Cancer Research', 118],
#  ['Oncology', 117],
#  ['Psychiatry', 116],
#  ['Data Storage Representation', 115],
#  ['Social Policy', 113],
#  ['Mathematical Modeling and Industrial Mathematics', 112],
#  ['Computer Appl. in Life Sciences', 111],
#  ['Software Engineering', 111],
#  ['Cryptology', 109],
#  ['Innovation/Technology Management', 107],
#  ['Business Mathematics', 105],
#  ['Computational Linguistics', 105],
#  ['Classical Mechanics', 104],
#  ['Sustainable Architecture/Green Buildings', 102],
#  ['Applications of Mathematics', 101],
#  ['Governance and Government', 101],
#  ['Biochemistry, general', 99],
#  ['Personality and Social Psychology', 97],
#  ['Earth System Sciences', 96],
#  ['Statistics for Social Sciences, Humanities, Law', 96],
#  ['Neurology', 96],
#  ['Political Science', 95],
#  ['Business Information Systems', 95],
#  ['Metabolic Diseases', 95],
#  ['Atmospheric Sciences', 94],
#  ['Engineering Mathematics', 94],
#  ['Life Sciences, general', 94],
#  ['Comparative Politics', 93],
#  ['Environmental Engineering/Biotechnology', 92],
#  ['Neuroradiology', 89],
#  ['Industrial Design', 88],
#  ['Pharmacology/Toxicology', 88],
#  ['Systems Biology', 87],
#  ['Nanotechnology and Microengineering', 87],
#  ['Physical Chemistry', 86],
#  ['Pediatrics', 85],
#  ['Operations Management', 84],
#  ['Linguistics, general', 83],
#  ['Psychology, general', 82],
#  ['Optics, Lasers, Photonics, Optical Devices', 82],
#  ['Linguistics', 82],
#  ['Information Systems Applications (incl. Internet)', 80],
#  ['Statistics', 79],
#  ['Theoretical, Mathematical and Computational Physics', 78],
#  ['Microarrays', 77],
#  ['Mathematical Applications in Computer Science', 77],
#  ['Environmental Policy', 77],
#  ['Organization', 76],
#  ['Statistical Theory and Methods', 76],
#  ['Hydrogeology', 76],
#  ['Probability Theory and Stochastic Processes', 75],
#  ['Surfaces and Interfaces, Thin Films', 75],
#  ['Energy Storage', 75],
#  ['Natural Hazards', 75],
#  ['Neurosurgery', 75],
#  ['Ethics', 73],
#  ['Statistics for Life Sciences, Medicine, Health Sciences', 73],
#  ['Library Science', 73],
#  ['Solid Mechanics', 72],
#  ['Quantum Physics', 72],
#  ['Orthopedics', 71],
#  ['Development Studies', 71],
#  ['Fire Science, Hazard Control, Building Safety', 71],
#  ['Statistics for Business, Management, Economics, Finance, Insurance', 70],
#  ['Occupational Medicine/Industrial Medicine', 70],
#  ['Biomedical Engineering/Biotechnology', 70],
#  ['Soil Science & Conservation', 69],
#  ['Cell Biology', 69],
#  ['Game Theory, Economics, Social and Behav. Sciences', 69],
#  ['Human Genetics', 68],
#  ['Computer System Implementation', 67],
#  ['Arts', 67],
#  ['Biological Techniques', 67],
#  ['Human Geography', 67],
#  ['Mechatronics', 66],
#  ['Anesthesiology', 66],
#  ['Combinatorics', 65],
#  ['Human Rights', 65],
#  ['Calculus of Variations and Optimal Control; Optimization', 65],
#  ['Pain Medicine', 64],
#  ['Microbiology', 64],
#  ['Media Management', 63],
#  ['Crime Control and Security', 63],
#  ['Plant Sciences', 62],
#  ['Production', 61],
#  ['Applications of Graph Theory and Complex Networks', 61],
#  ['Quality Control, Reliability, Safety and Risk', 61],
#  ['IT Law, Media Law, Intellectual Property', 59],
#  ['Criminology and Criminal Justice, general', 59],
#  ['Business Strategy/Leadership', 58],
#  ['Diagnostic Radiology', 58],
#  ['Ultrasound', 58],
#  ['Performing Arts', 58],
#  ['Behavioral Sciences', 57],
#  ['Gastroenterology', 57],
#  ['Economic Growth', 56],
#  ['Marketing', 56],
#  ['Endocrinology', 56],
#  ['Quality of Life Research', 55],
#  ['Genetics and Genomics', 54],
#  ['Regenerative Medicine/Tissue Engineering', 54],
#  ['Human Physiology', 54],
#  ['Political Communication', 54],
#  ['Crime and Society', 53],
#  ['Cardiology', 53],
#  ['Electronic Circuits and Devices', 52],
#  ['Polymer Sciences', 52],
#  ['Interventional Radiology', 52],
#  ['Entrepreneurship', 51],
#  ['Risk Management', 50],
#  ['Condensed Matter Physics', 50],
#  ['History', 50],
#  ['Physics, general', 50],
#  ['Math. Applications in Chemistry', 50],
#  ['Water, general', 49],
#  ['Health Care Management', 49],
#  ['Tribology, Corrosion and Coatings', 49],
#  ['Optical and Electronic Materials', 49],
#  ['Industrial Organization', 49],
#  ['Prison and Punishment', 49],
#  ['Mathematics of Computing', 48],
#  ['Health Psychology', 48],
#  ['Epidemiology', 48],
#  ['Urology', 48],
#  ['Environmental Economics', 47],
#  ['Urban Studies/Sociology', 47],
#  ['Food Microbiology', 47],
#  ['Pharmacotherapy', 47],
#  ['Health Administration', 47],
#  ['Surgical Oncology', 47],
#  ['Gynecology', 46],
#  ['Knowledge based Systems', 46],
#  ['Gender Studies', 46],
#  ['Language and Literature', 46],
#  ['Operations Research, Management Science', 45],
#  ['Political Sociology', 45],
#  ['Immunology', 45],
#  ['Social Justice, Equality and Human Rights', 45],
#  ['Economic Theory/Quantitative Economics/Mathematical Methods', 44],
#  ['Metallic Materials', 44],
#  ['Ecosystems', 43],
#  ['International and Comparative Education', 43],
#  ['Inorganic Chemistry', 43],
#  ['Social Structure, Social Inequality', 42],
#  ['European Law', 42],
#  ['Cultural and Media Studies', 42],
#  ['Geography', 42],
#  ['Ontology', 42],
#  ['Philosophy of Language', 42],
#  ['Computers and Society', 41],
#  ['Emergency Medicine', 41],
#  ['Reproductive Medicine', 41],
#  ['Animal Genetics and Genomics', 41],
#  ['Computation by Abstract Devices', 41],
#  ['Statistical Physics and Dynamical Systems', 40],
#  ['Waste Management/Waste Technology', 40],
#  ['Health Policy', 40],
#  ['Higher Education', 40],
#  ['Microsoft and .NET', 40],
#  ['Child and Adolescent Psychiatry', 40],
#  ['Microbial Genetics and Genomics', 40],
#  ['Business Ethics', 39],
#  ['Facility Management', 39],
#  ['Media Sociology', 39],
#  ['Critical Criminology', 39],
#  ['Minimally Invasive Surgery', 39],
#  ['Cultural Heritage', 39],
#  ['Philosophy of Science', 39],
#  ['Hepatology', 39],
#  ['Oceanography', 38],
#  ['e-Commerce/e-business', 38],
#  ['Abdominal Surgery', 38],
#  ['Pharmaceutical Sciences/Technology', 37],
#  ['Health Promotion and Disease Prevention', 37],
#  ['Media and Communication', 37],
#  ['Public International Law', 37],
#  ['Organic Chemistry', 37],
#  ['Remote Sensing/Photogrammetry', 37],
#  ['Intensive / Critical Care Medicine', 37],
#  ['Surgical Orthopedics', 36],
#  ['R & D/Technology Policy', 36],
#  ['Nutrition', 36],
#  ['Molecular Medicine', 36],
#  ['Economics, general', 35],
#  ['International Security Studies', 35],
#  ['Nuclear Medicine', 35],
#  ['Biological Psychology', 35],
#  ['Ethics and Values in Social Work', 35],
#  ['African Politics', 35],
#  ['Neurobiology', 35],
#  ['Hydrology/Water Resources', 35],
#  ['Computer Hardware', 34],
#  ['Mathematics, general', 34],
#  ['Pollution, general', 34],
#  ['Social Work', 34],
#  ['Zoology', 34],
#  ['Community and Environmental Psychology', 34],
#  ['Public Administration', 34],
#  ['Math. Appl. in Environmental Science', 34],
#  ['Theoretical and Computational Chemistry', 34],
#  ['Java', 33],
#  ['Dentistry', 33],
#  ['Military and Defence Studies', 33],
#  ['Regional/Spatial Science', 33],
#  ['Philosophy of Technology', 33],
#  ['Philosophy of Mind', 33],
#  ['Architecture / Design', 33],
#  ['Digital/New Media', 33],
#  ['Labor Economics', 33],
#  ['Psychometrics', 33],
#  ['Criminal Law and Criminal Procedure Law', 33],
#  ['Evolutionary Biology', 33],
#  ['Mathematical Models of Cognitive Processes and Neural Networks', 32],
#  ['Applied and Technical Physics', 32],
#  ['Philosophy, general', 32],
#  ['Finance, general', 32],
#  ['Political Theory', 32],
#  ['Archaeology', 32],
#  ['Structural Geology', 32],
#  ['Theoretical and Applied Mechanics', 32],
#  ['Coding and Information Theory', 31],
#  ['Industries', 31],
#  ['Big Data/Analytics', 31],
#  ['Physiotherapy', 31],
#  ['Occupational Therapy', 31],
#  ['Applied Statistics', 31],
#  ['Algorithm Analysis and Problem Complexity', 30],
#  ['Meteorology', 30],
#  ['Cities, Countries, Regions', 30],
#  ['Music', 30],
#  ['Sustainability Management', 30],
#  ['Teaching and Teacher Education', 30],
#  ['Cardiac Surgery', 30],
#  ['History, general', 30],
#  ['Sources and Subjects of International Law, International Organizations',
#   30],
#  ['Plant Genetics and Genomics', 30],
#  ['Learning and Instruction', 30],
#  ['International Economic Law, Trade Law', 29],
#  ['Offshore Engineering', 29],
#  ['Interaction Design', 29],
#  ['International Environmental Law', 29],
#  ['European History', 29],
#  ['World History, Global and Transnational History', 29],
#  ['Colorectal Surgery', 29],
#  ['Civil Law', 29],
#  ['International Criminal Law', 29],
#  ['Infectious Diseases', 29],
#  ['Engineering Acoustics', 28],
#  ['Social Choice/Welfare Economics/Public Choice/Political Economy', 28],
#  ['Theories of Law, Philosophy of Law, Legal History', 28],
#  ['International Relations', 28],
#  ['Human Resource Management', 28],
#  ['Geriatrics/Gerontology', 28],
#  ['Climate Change/Climate Change Impacts', 28],
#  ['Political History', 28],
#  ['Geographical Information Systems/Cartography', 28],
#  ['Energy Materials', 27],
#  ['Python', 27],
#  ['Environmental and Sustainability Education', 27],
#  ['Environmental Law/Policy/Ecojustice', 27],
#  ['Positive Psychology', 27],
#  ['General Surgery', 27],
#  ['Cultural History', 27],
#  ['Pharmacy', 27],
#  ['Statistics and Computing/Statistics Programs', 27],
#  ['Dispute Resolution, Mediation, Arbitration', 27],
#  ['Computer Applications in Chemistry', 27],
#  ['Environmental Science and Engineering', 27],
#  ['Social Work and Community Development', 26],
#  ['Medical Microbiology', 26],
#  ['Web Development', 26],
#  ['Religion and Psychology', 26],
#  ['Neuropsychology', 26],
#  ['Vascular Surgery', 26],
#  ['Migration', 26],
#  ['Microeconomics', 26],
#  ['Fundamentals of Law', 26],
#  ['Epistemology', 26],
#  ['Convex and Discrete Geometry', 26],
#  ['Philosophy of Law', 26],
#  ['Fluid- and Aerodynamics', 25],
#  ['Anatomy', 25],
#  ['History of Philosophy', 25],
#  ['Asian Economics', 25],
#  ['International Economics', 25],
#  ['General Practice / Family Medicine', 25],
#  ['Physiology', 25],
#  ['Economic Policy', 25],
#  ['Landscape/Regional and Urban Planning', 25],
#  ['Anthropology', 24],
#  ['Security Science and Technology', 24],
#  ['Programming Techniques', 24],
#  ['International Organization', 24],
#  ['Ceramics, Glass, Composites, Natural Materials', 24],
#  ['Climate, general', 24],
#  ['Ethnicity, Class, Gender and Crime', 24],
#  ['Asian Business', 23],
#  ['Biodiversity', 23],
#  ['Latino Culture', 23],
#  ['Psychotherapy and Counseling', 23],
#  ['Nursing Research', 23],
#  ['Social History', 23],
#  ['Finance', 23],
#  ['Geology', 23],
#  ['Animal Anatomy / Morphology / Histology', 23],
#  ['Mineral Resources', 23],
#  ['Particle and Nuclear Physics', 22],
#  ['Mechanical Statics and Structures', 22],
#  ['Politics of the Welfare State', 22],
#  ['Digital Humanities', 22],
#  ['Sociology of Education', 22],
#  ['Professional & Vocational Education', 22],
#  ['Diplomacy', 22],
#  ['Plant Physiology', 22],
#  ['Freshwater & Marine Ecology', 22],
#  ['Financial Engineering', 22],
#  ['Financial Services', 22],
#  ['Fossil Fuels (incl. Carbon Capture)', 22],
#  ['Math Applications in Computer Science', 22],
#  ['Legal Aspects of Computing', 22],
#  ['Mathematical Applications in the Physical Sciences', 21],
#  ['Software Management', 21],
#  ['Development Economics', 21],
#  ['Employee Health and Wellbeing', 21],
#  ['Aging', 21],
#  ['Thoracic Surgery', 21],
#  ['Sociology of Family, Youth and Aging', 21],
#  ['Political Economy/Economic Systems', 21],
#  ['Diversity Management/Women in Business', 21],
#  ['Social Philosophy', 21],
#  ['Theory of Medicine/Bioethics', 21],
#  ['Sports Medicine', 21],
#  ['Proteomics', 21],
#  ['Climate Change Management and Policy', 20],
#  ['Corporate Governance', 20],
#  ['Biochemical Engineering', 20],
#  ['Behavioral/Experimental Economics', 20],
#  ['Microbial Ecology', 20],
#  ['Criminological Theory', 20],
#  ['Safety in Chemistry, Dangerous Goods', 20],
#  ['Socio-legal Studies', 20],
#  ['Climatology', 20],
#  ['Diabetes', 20],
#  ['Quantum Information Technology, Spintronics', 20],
#  ['Computer Appl. in Administrative Data Processing', 19],
#  ['Supply Chain Management', 19],
#  ['History of Technology', 19],
#  ['Pathology', 19],
#  ['Green Chemistry', 19],
#  ['International Relations Theory', 19],
#  ['Developmental Psychology', 19],
#  ['Demography', 19],
#  ['Virology', 19],
#  ['Privacy', 18],
#  ['Electrochemistry', 18],
#  ['Human Resource Development', 18],
#  ['Social Care', 18],
#  ['Electoral Politics', 18],
#  ['Terrorism and Political Violence', 18],
#  ['Crime and the Media', 18],
#  ['Economic Geography', 18],
#  ['Philosophy of the Social Sciences', 18],
#  ['Economic Psychology', 18],
#  ['Elementary Particles, Quantum Field Theory', 18],
#  ['Pneumology/Respiratory System', 18],
#  ['Gene Function', 18],
#  ['Accounting/Auditing', 18],
#  ['Health Economics', 17],
#  ['Natural Resource and Energy Economics', 17],
#  ['Tourism Management', 17],
#  ['Administration, Organization and Leadership', 17],
#  ['Political Philosophy', 17],
#  ['Sociology of Work', 17],
#  ['Asian Politics', 17],
#  ['Politics and Gender', 17],
#  ['Ophthalmology', 17],
#  ['Forestry', 17],
#  ['Hematology', 17],
#  ['Middle Eastern Politics', 17],
#  ['Political Science and International Relations, general', 17],
#  ['Literature', 17],
#  ['Pediatric Surgery', 17],
#  ['Numerical and Computational Physics, Simulation', 17],
#  ['Macroeconomics/Monetary Economics//Financial Economics', 17],
#  ['Graph Theory', 16],
#  ['Numerical Analysis', 16],
#  ['Online Marketing/Social Media', 16],
#  ['Obstetrics/Perinatology/Midwifery', 16],
#  ['Engineering Ethics', 16],
#  ['Philosophy of Religion', 16],
#  ['Computer Appl. in Arts and Humanities', 16],
#  ['Legislative and Executive Politics', 16],
#  ['Otorhinolaryngology', 16],
#  ['Humanities and Social Sciences, multidisciplinary', 16],
#  ['Nuclear Energy', 15],
#  ['Astronomy, Astrophysics and Cosmology', 15],
#  ['Media Design', 15],
#  ['Antibodies', 15],
#  ['Educational Policy and Politics', 15],
#  ['Public Law', 15],
#  ['Veterinary Medicine/Veterinary Science', 15],
#  ['Nuclear Physics, Heavy Ions, Hadrons', 15],
#  ['Catalysis', 15],
#  ['Pedagogic Psychology', 15],
#  ['Applied Microbiology', 15],
#  ['Coastal Sciences', 15],
#  ['Public Finance', 15],
#  ['Biostatistics', 15],
#  ['Law and Economics', 15],
#  ['Continental Philosophy', 15],
#  ['Geochemistry', 15],
#  ['Nanoscale Science and Technology', 15],
#  ['Rehabilitation', 15],
#  ['Industrial Pollution Prevention', 15],
#  ['Mobile Computing', 14],
#  ['Mathematics in Music', 14],
#  ['Thermodynamics', 14],
#  ['Game Development', 14],
#  ['Physical Geography', 14],
#  ['Climate Change', 14],
#  ['History of Modern Europe', 14],
#  ['Rheumatology', 14],
#  ['Proctology', 14],
#  ['Analysis', 13],
#  ['Biomechanics', 13],
#  ['Development and Sustainability', 13],
#  ['Globalization', 13],
#  ['Nursing', 13],
#  ['Open Source', 13],
#  ['Emotion', 13],
#  ['Medical Education', 13],
#  ['Research Methods in Criminology', 13],
#  ['Plant Pathology', 13],
#  ['Water and Health', 13],
#  ['Logic', 13],
#  ['Medical and Radiation Physics', 13],
#  ['Cultural Policy and Politics', 13],
#  ['Social Anthropology', 13],
#  ['Organized Crime', 13],
#  ['Magnetism, Magnetic Materials', 13],
#  ['Nuclear Chemistry', 13],
#  ['Social Media', 13],
#  ['Documentation and Information in Chemistry', 13],
#  ['Real Functions', 13],
#  ['Radiotherapy', 13],
#  ['Architecture, general', 13],
#  ['Psychotherapy', 13],
#  ['Science Education', 13],
#  ['Cultural Studies', 13],
#  ['Logistics', 12],
#  ['Medicinal Chemistry', 12],
#  ['Plant Breeding/Biotechnology', 12],
#  ['Religious Studies', 12],
#  ['Spirituality', 12],
#  ['History of World War II and the Holocaust', 12],
#  ['Urban Ecology', 12],
#  ['Popular Culture', 12],
#  ['Population Economics', 12],
#  ['Solid State Physics', 12],
#  ['Laboratory Medicine', 12],
#  ['Atomic/Molecular Structure and Spectra', 12],
#  ['Quantum Field Theories, String Theory', 12],
#  ['Nephrology', 12],
#  ['Psycholinguistics', 12],
#  ['Vaccine', 12],
#  ['The Computing Profession', 11],
#  ['Engineering/Technology Education', 11],
#  ['Creativity and Arts Education', 11],
#  ['Economy-wide Country Studies', 11],
#  ['Social/Human Development Studies', 11],
#  ['Agricultural Economics', 11],
#  ['Nanochemistry', 11],
#  ['Life course', 11],
#  ['Practice and Hospital Management', 11],
#  ['Organizational Studies, Economic Sociology', 11],
#  ['Nursing Education', 11],
#  ['Research Ethics', 11],
#  ['Developmental Biology', 11],
#  ['Migration, "Womens Studies"', 11],
#  ['Imperialism and Colonialism', 11],
#  ['History of Economic Thought/Methodology', 11],
#  ['Metaphysics', 11],
#  ['Astrophysics and Astroparticles', 11],
#  ['Atomic, Molecular, Optical and Plasma Physics', 11],
#  ['Water Quality/Water Pollution', 11],
#  ['Acoustics', 11],
#  ['Membrane Biology', 11],
#  ['Quantum Computing', 11],
#  ['Data Structures', 11],
#  ['Memory Structures', 11],
#  ['Nature Conservation', 11],
#  ['Fourier Analysis', 10],
#  ['Spectroscopy/Spectrometry', 10],
#  ['Curriculum Studies', 10],
#  ['History of Science', 10],
#  ['Foreign Policy', 10],
#  ['Cultural Geography', 10],
#  ['Animal Physiology', 10],
#  ['Research Skills', 10],
#  ['Language Policy and Planning', 10],
#  ['History of the Americas', 10],
#  ['Plant Biochemistry', 10],
#  ['Paleontology', 10],
#  ['Medical Law', 10],
#  ['Parasitology', 10],
#  ['Bioorganic Chemistry', 10],
#  ['Differential Geometry', 10],
#  ['Biological Microscopy', 10],
#  ['Classical and Quantum Gravitation, Relativity Theory', 10],
#  ['Soft and Granular Matter, Complex Fluids and Microfluidics', 10],
#  ['Maternal and Child Health', 10],
#  ['Personal Computing', 10],
#  ['Animal Biochemistry', 10],
#  ['Conservation Biology/Ecology', 10],
#  ['Landscape Ecology', 10],
#  ['Abstract Harmonic Analysis', 9],
#  ['Mass Spectrometry', 9],
#  ['Business Strategy/Leadership, "Womens Studies"', 9],
#  ['Education Policy', 9],
#  ['Comparative Social Policy', 9],
#  ['Gender and Sexuality', 9],
#  ['Family', 9],
#  ['Sociology of Citizenship', 9],
#  ['Modern History', 9],
#  ['Constitutional Law', 9],
#  ['Labor History', 9],
#  ['African History', 9],
#  ['Astronomy, Observations and Techniques', 9],
#  ['Screen Studies', 9],
#  ['International Business', 9],
#  ['Traumatic Surgery', 9],
#  ['Angiology', 9],
#  ['Mathematical Methods in Physics', 9],
#  ['Assessment, Testing and Evaluation', 9],
#  ['Biological and Physical Anthropology', 9],
#  ['Particle Acceleration and Detection, Beam Physics', 8],
#  ['Computing Milieux', 8],
#  ['Corporate Environmental Management', 8],
#  ['Asian History', 8],
#  ['Geriatric Care', 8],
#  ['Visualization', 8],
#  ['Early Childhood Education', 8],
#  ['Literacy', 8],
#  ['Sociology of Culture', 8],
#  ['History of France', 8],
#  ['Transportation', 8],
#  ['Critical Theory', 8],
#  ['Cosmology', 8],
#  ['German Idealism', 8],
#  ['Audio-Visual Culture', 8],
#  ['Mathematical Physics', 8],
#  ['Data-driven Science, Modeling and Theory Building', 8],
#  ['Terrestrial Pollution', 8],
#  ['Performance and Reliability', 8],
#  ['Control Structures and Microprogramming', 7],
#  ['Security', 7],
#  ['Light Construction, Steel Construction, Timber Construction', 7],
#  ['Nursing Ethics', 7],
#  ['Protein Science', 7],
#  ['Mineralogy', 7],
#  ['Plasma Physics', 7],
#  ['Solid Construction', 7],
#  ['Medical Sociology', 7],
#  ['Medical Anthropology', 7],
#  ['Stem Cells', 7],
#  ['Forensic Psychology', 7],
#  ['Child and School Psychology', 7],
#  ['Neurochemistry', 7],
#  ['Hermeneutics', 7],
#  ['Political Leadership', 7],
#  ['Fiction', 7],
#  ['Transplant Surgery', 7],
#  ['Oral and Maxillofacial Surgery', 7],
#  ['Rehabilitation Medicine', 7],
#  ['Geoecology/Natural Processes', 7],
#  ['Crystallography and Scattering Methods', 7],
#  ['Water Industry/Water Technologies', 7],
#  ['Cardiac Imaging', 7],
#  ['Drug Safety and Pharmacovigilance', 7],
#  ['Econometrics', 7],
#  ['Quantitative Finance', 7],
#  ['Banking', 7],
#  ['Logic Design', 6],
#  ['Partial Differential Equations', 6],
#  ['Trade', 6],
#  ['Urban Economics', 6],
#  ['Applied Linguistics', 6],
#  ['Spectroscopy and Microscopy', 6],
#  ['Applications of Nonlinear Dynamics and Chaos Theory', 6],
#  ['Memory Studies', 6],
#  ['Mycology', 6],
#  ['Behavioral Therapy', 6],
#  ['Enzymology', 6],
#  ['History of Italy', 6],
#  ['Religion and Education', 6],
#  ['Criminal Behavior', 6],
#  ['Adaptation Studies', 6],
#  ['Educational Philosophy', 6],
#  ['Metabolomics', 6],
#  ['Drug Resistance', 6],
#  ['Dermatology', 6],
#  ['Mathematical and Computational Biology', 6],
#  ['Bayesian Inference', 6],
#  ['Plastic Surgery', 6],
#  ['Information and Communication, Circuits', 6],
#  ['Corporate Finance', 6],
#  ['Psychology Research', 6],
#  ['Experimental Psychology', 6],
#  ['Latin American/Caribbean Literature', 6],
#  ['Latin American Cinema and TV', 6],
#  ['Latin American Culture', 6],
#  ['Combinatorial Libraries', 6],
#  ['Economic Geology', 5],
#  ['Real Estate Management', 5],
#  ['Sales/Distribution', 5],
#  ['Speech Pathology', 5],
#  ['Environmental Physics', 5],
#  ['Asian Culture', 5],
#  ['Medical Biochemistry', 5],
#  ['Urban History', 5],
#  ['Financial History', 5],
#  ['Literary Theory', 5],
#  ['Functional Analysis', 5],
#  ['European Cinema and TV', 5],
#  ['Comparative Literature', 5],
#  ['Emerging Markets/Globalization', 5],
#  ['Business Process Management', 5],
#  ['Philosophy of Medicine', 5],
#  ['Tropical Medicine', 5],
#  ['Health Services Research', 5],
#  ['Clinical Nutrition', 5],
#  ['Surveying', 5],
#  ['Gene Therapy', 5],
#  ['Environmental Sociology', 5],
#  ['Marine & Freshwater Sciences', 5],
#  ['History and Philosophical Foundations of Physics', 5],
#  ['Vertebrates', 5],
#  ['Numeric Computing', 4],
#  ['Language Education', 4],
#  ['Forensic Science', 4],
#  ['Moral Philosophy', 4],
#  ['African American Culture', 4],
#  ['Politics and Religion', 4],
#  ['Semiconductors', 4],
#  ['Animation', 4],
#  ['Genre', 4],
#  ['Algebra', 4],
#  ['Plant Systematics/Taxonomy/Biogeography', 4],
#  ['Biogeosciences', 4],
#  ['Entomology', 4],
#  ['Animal Ecology', 4],
#  ['Wood Science & Technology', 4],
#  ['Linear and Multilinear Algebras, Matrix Theory', 4],
#  ['Gene Expression', 4],
#  ['Energy, general', 4],
#  ['Sexual Behavior', 4],
#  ['Plant Ecology', 4],
#  ['Theoretical Ecology/Statistics', 4],
#  ['Psychological Methods/Evaluation', 4],
#  ['Business Taxation/Tax Law', 4],
#  ['Quantum Optics', 4],
#  ['Head and Neck Surgery', 4],
#  ['Popular Science, general', 4],
#  ['Semantics', 4],
#  ['Regional and Cultural Studies', 4],
#  ['Hardware and Maker', 3],
#  ['Career Skills', 3],
#  ['Learning & Instruction', 3],
#  ['Apple and iOS', 3],
#  ['Surface and Interface Science, Thin Films', 3],
#  ['Education Economics', 3],
#  ['Youth Culture', 3],
#  ['Corporate Social Responsibility', 3],
#  ['Development Policy', 3],
#  ['Family Business', 3],
#  ['History of China', 3],
#  ['History of Religion', 3],
#  ['Gothic Studies', 3],
#  ['Nineteenth-Century Literature', 3],
#  ['Literature, general', 3],
#  ['History of Education', 3],
#  ['Twentieth-Century Literature', 3],
#  ['American Cinema and TV', 3],
#  ['European Literature', 3],
#  ['International Political Economy', 3],
#  ['Psychosocial Studies', 3],
#  ['Sociological Theory', 3],
#  ['Market Research/Competitive Intelligence', 3],
#  ['Forensic Medicine', 3],
#  ['Insurance', 3],
#  ['Animal Systematics/Taxonomy/Biogeography', 3],
#  ['Psychopharmacology', 3],
#  ['Energy Efficiency', 3],
#  ['Blood Transfusion Medicine', 3],
#  ['Educational Psychology', 3],
#  ['Primary Care Medicine', 3],
#  ['Allergology', 3],
#  ['Agricultural Ethics', 3],
#  ['Research Methods in Education', 3],
#  ['Input/Output and Data Communications', 3],
#  ['Cell Culture', 3],
#  ['Commercial Law', 3],
#  ['Receptors', 3],
#  ['Veterinary Microbiology, Parasitology and Infectious Diseases', 3],
#  ['European Integration', 3],
#  ['Mathematics Education', 3],
#  ['Discrete Mathematics in Computer Science', 2],
#  ['Sociolinguistics', 2],
#  ['Environment Studies', 2],
#  ['Environmental Geography', 2],
#  ['Consumer Behavior', 2],
#  ['Critical Thinking', 2],
#  ['Skills', 2],
#  ['Building Physics, HVAC', 2],
#  ['e-Business/e-Commerce', 2],
#  ['North American Literature', 2],
#  ['Contemporary Literature', 2],
#  ['Poetry and Poetics', 2],
#  ['Start-Ups/Venture Capital', 2],
#  ['Cytogenetics', 2],
#  ['Sport Science', 2],
#  ['Sport Education and Didactics', 2],
#  ['Protein Structure', 2],
#  ['Technology and Digital Education', 2],
#  ['Plant Anatomy/Development', 2],
#  ['Embryology', 2],
#  ['Lipidology', 2],
#  ['Organometallic Chemistry', 2],
#  ['Family, Group and Systematic Therapy', 2],
#  ['Phase Transitions and Multiphase Systems', 2],
#  ['Forestry Management', 2],
#  ['Fish & Wildlife Biology & Management', 2],
#  ['Cross Cultural Psychology', 2],
#  ['Law of the Sea, Air and Outer Space', 2],
#  ['Philosophy of Biology', 2],
#  ['Terrestial Ecology', 2],
#  ['Business Finance', 2],
#  ['Planetology', 2],
#  ['Palliative Medicine', 2],
#  ['Microengineering', 2],
#  ['Communication Studies', 2],
#  ['Journalism', 2],
#  ['Phenomenology', 2],
#  ['North American Economics', 2],
#  ['Management Education', 2],
#  ['Historical Linguistics', 2],
#  ['Syntax', 2],
#  ['Computer Crime', 1],
#  ['Mathematical Logic and Formal Languages', 1],
#  ['Logics and Meanings of Programs', 1],
#  ['Research Methodology', 1],
#  ['Heterodox Economics', 1],
#  ['African Culture', 1],
#  ['Knowledge Management', 1],
#  ['Business Consulting', 1],
#  ['History of Medieval Europe', 1],
#  ['Social Theory', 1],
#  ['Study and Learning Skills', 1],
#  ['History of South Asia', 1],
#  ['Eukaryotic Microbiology', 1],
#  ['Approximations and Expansions', 1],
#  ['Institutional/Evolutionary Economics', 1],
#  ['Cardiovascular Biology', 1],
#  ['Operator Theory', 1],
#  ['Topology', 1],
#  ['Sedimentology', 1],
#  ['Cybercrime', 1],
#  ['Tree Biology', 1],
#  ['Bioethics', 1],
#  ['Algebraic Topology', 1],
#  ['Development Aid', 1],
#  ['History of Mathematical Sciences', 1],
#  ['Nuclear Fusion', 1],
#  ['Religious Studies, general', 1],
#  ['Number Theory', 1],
#  ['Field Theory and Polynomials', 1],
#  ['Functions of a Complex Variable', 1],
#  ['Transnational Crime', 1],
#  ['Capital Markets', 1],
#  ['Financial Law/Fiscal Law', 1],
#  ['Community & Population Ecology', 1],
#  ['Applied Ecology', 1],
#  ['Animal Models', 1],
#  ['Investments and Securities', 1],
#  ['Group Theory and Generalizations', 1],
#  ['Corporate Communication/Public Relations', 1],
#  ['Classical Electrodynamics', 1],
#  ['Protein-Ligand Interactions', 1],
#  ['Cytokines and Growth Factors', 1],
#  ['Genetic Engineering', 1],
#  ['Cell Cycle Analysis', 1],
#  ['Cell Physiology', 1],
#  ['Psychosomatic Medicine', 1],
#  ['Pharmacoeconomics and Health Outcomes', 1],
#  ['Strongly Correlated Systems, Superconductivity', 1],
#  ['Complementary & Alternative Medicine', 1],
#  ['Consulting, Supervision and Coaching', 1],
#  ['Comparative Linguistics', 1],
#  ['Philology', 1],
#  ['Urban Geography / Urbanism (inc. megacities, cities, towns)', 1],
#  ['Urbanism', 1],
#  ['Cultural Economics', 1],
#  ['Hand Surgery', 1],
#  ['Lifelong Learning/Adult Education', 1],
#  ['Professional and Vocational Education', 1],
#  ['Russian', 1],
#  ['Geometry', 1],
#  ['Language Teaching', 1],
#  ['Philosophy of Education', 1],
#  ['Ordinary Differential Equations', 1],
#  ['Project Management', 1],
#  ['Nursing Management', 1],
#  ['Enterprise Architecture', 1],
#  ['Early Modern/Renaissance Literature', 1],
#  ['British and Irish Literature', 1],
#  ['Theatre History', 1]]

# %%
top_frec = [x[0] for x in frec if x[1]>200]
top_frec
# Out:
# ['Engineering',
#  'Artificial Intelligence',
#  'Computational Intelligence',
#  'Computer Science',
#  'Communications Engineering, Networks',
#  'Control, Robotics, Mechatronics',
#  'Cyber-physical systems, IoT',
#  'Professional Computing',
#  'Mechanical Engineering',
#  'Data Structures and Information Theory',
#  'Medicine & Public Health',
#  'Science, Humanities and Social Sciences, multidisciplinary',
#  'Industrial and Production Engineering',
#  'Machine Learning',
#  'Computer Communication Networks',
#  'Manufacturing, Machines, Tools, Processes',
#  'Robotics and Automation',
#  'Computer Science, general',
#  'Data Mining and Knowledge Discovery',
#  'Signal, Image and Speech Processing',
#  'Data Engineering',
#  'Control and Systems Theory',
#  'Image Processing and Computer Vision',
#  'Aerospace Technology and Astronautics',
#  'Business and Management',
#  'Computer Imaging, Vision, Pattern Recognition and Graphics',
#  'Transportation Technology and Traffic Engineering',
#  'Computational Biology/Bioinformatics',
#  'Science, multidisciplinary',
#  'Statistics, general',
#  'Life Sciences',
#  'Automotive Engineering',
#  'Multimedia Information Systems',
#  'Information Storage and Retrieval',
#  'Biomedical Engineering and Bioengineering',
#  'Electronics and Microelectronics, Instrumentation',
#  'User Interfaces and Human Computer Interaction',
#  'Wireless and Mobile Communication',
#  'Biomedicine',
#  'Special Purpose and Application-Based Systems',
#  'Computational Science and Engineering',
#  'Mathematical and Computational Engineering',
#  'Engineering Design',
#  'Computer Systems Organization and Communication Networks',
#  'Vibration, Dynamical Systems, Control',
#  'Environment, general',
#  'Engineering Economics, Organization, Logistics, Marketing',
#  'Bioinformatics',
#  'Science and Technology Studies',
#  'Mobile and Network Security',
#  'Materials Science, general',
#  'Probability and Statistics in Computer Science',
#  'Energy Systems',
#  'IT in Business',
#  'Circuits and Systems',
#  'Operations Research/Decision Theory',
#  'Building Construction and Design',
#  'Sustainable Development',
#  'Environment',
#  'Natural Language Processing (NLP)',
#  'Political Science and International Relations',
#  'Systems and Data Security',
#  'Machinery and Machine Elements',
#  'Building Repair and Maintenance',
#  'Earth Sciences',
#  'Chemistry',
#  'Information Systems Applications (incl.Internet)',
#  'Analytical Chemistry',
#  'Systems Theory, Control',
#  'Materials Engineering',
#  'Software Engineering/Programming and Operating Systems',
#  'Computer Applications',
#  'Complex Systems',
#  'Social Sciences',
#  'Electrical Engineering',
#  'Energy Policy, Economics and Management',
#  'Biomedicine, general',
#  'Computer-Aided Engineering (CAD, CAE) and Design',
#  'Neurosciences',
#  'Business and Management, general',
#  'Imaging / Radiology',
#  'Monitoring/Environmental Analysis',
#  'Psychology',
#  'Health Informatics',
#  'Power Electronics, Electrical Machines and Networks',
#  'Energy',
#  'Information Systems and Communication Service',
#  'Civil Engineering',
#  'Sociology, general',
#  'Complexity',
#  'Database Management',
#  'Robotics',
#  'Medicine/Public Health, general',
#  'Mathematics',
#  'Public Policy',
#  'Signal,Image and Speech Processing',
#  'Materials Science',
#  'Operating Systems',
#  'Education, general',
#  'Geotechnical Engineering & Applied Earth Sciences',
#  'Processor Architectures',
#  'Engineering, general',
#  'Structural Materials',
#  'Pattern Recognition']

# %%
excluded = ["Engineering"]
temp = [[x.replace("'","") for x in i if x.replace("'","") in top_frec and x.replace("'","") not in  excluded ] for i in areas]
#data["subjects"] =[','.join(x) for x in temp] 
data["subjects"] = temp

# %%
data["subjects_size"]=  [len(x) for x in data["subjects"] ]

# %%
print(len(data))
data = data[data["subjects_size"] >0]
print(len(data))
# Out:
# 22494
# 21633

# %%
data = data.drop(columns=["subjects_size"])

# %%
data.to_csv("spring/total.csv",index=False) 
data = pd.read_csv("spring/total.csv")

# %%
# There are some terms with occurrence as low as 1.
print(sum(data["subjects"].value_counts() == 1))

# How many unique terms?
print(data["subjects"].nunique())
# Out:
# 117
# 896

# %%
data_fil = data.groupby("subjects").filter(lambda x: len(x) > 1)
data_fil.shape
# Out:
# (21516, 6)

# %%
data_fil.columns = ['id','idioma', 'titulo','genero', 'abstract', 'categorias']

# %%
data_fil.to_csv("spring/total.csv",index=False)
